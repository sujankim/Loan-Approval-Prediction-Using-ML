# %% [markdown]
# # 1. Importing necessary Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import imblearn         
from collections import Counter
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split,cross_val_score, GridSearchCV
from sklearn import metrics
from sklearn.metrics import classification_report
from pickle import dump, load
import mlflow
import mlflow.sklearn
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # 2. Importing Dataset

# %%
training_data = pd.read_csv('./Dataset/Training Data.csv')
training_data.head()
# Out:
#    Id   Income  Age  Experience Married/Single House_Ownership Car_Ownership  \
# 0   1  1303834   23           3         single          rented            no
# 1   2  7574516   40          10         single          rented            no
# 2   3  3991815   66           4        married          rented            no
# 3   4  6256451   41           2         single          rented           yes
# 4   5  5768871   47          11         single          rented            no
#
#             Profession                 CITY           STATE  CURRENT_JOB_YRS  \
# 0  Mechanical_engineer                 Rewa  Madhya_Pradesh                3
# 1   Software_Developer             Parbhani     Maharashtra                9
# 2     Technical_writer            Alappuzha          Kerala                4
# 3   Software_Developer          Bhubaneswar          Odisha                2
# 4        Civil_servant  Tiruchirappalli[10]      Tamil_Nadu                3
#
#    CURRENT_HOUSE_YRS  Risk_Flag
# 0                 13          0
# 1                 13          0
# 2                 10          0
# 3                 12          1
# 4                 14          1

# %%
test_data = pd.read_csv('./Dataset/Test Data.csv')
test_data.head()
# Out:
#    ID   Income  Age  Experience Married/Single House_Ownership Car_Ownership  \
# 0   1  7393090   59          19         single          rented            no
# 1   2  1215004   25           5         single          rented            no
# 2   3  8901342   50          12         single          rented            no
# 3   4  1944421   49           9        married          rented           yes
# 4   5    13429   25          18         single          rented           yes
#
#     Profession        CITY        STATE  CURRENT_JOB_YRS  CURRENT_HOUSE_YRS
# 0    Geologist       Malda  West Bengal                4                 13
# 1  Firefighter       Jalna  Maharashtra                5                 10
# 2       Lawyer       Thane  Maharashtra                9                 14
# 3      Analyst       Latur  Maharashtra                3                 12
# 4     Comedian  Berhampore  West Bengal               13                 11

# %%
training_data.shape
# Out:
# (252000, 13)

# %%
training_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 252000 entries, 0 to 251999
# Data columns (total 13 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Id                 252000 non-null  int64
#  1   Income             252000 non-null  int64
#  2   Age                252000 non-null  int64
#  3   Experience         252000 non-null  int64
#  4   Married/Single     252000 non-null  object
#  5   House_Ownership    252000 non-null  object
#  6   Car_Ownership      252000 non-null  object
#  7   Profession         252000 non-null  object
#  8   CITY               252000 non-null  object
#  9   STATE              252000 non-null  object
#  10  CURRENT_JOB_YRS    252000 non-null  int64
#  11  CURRENT_HOUSE_YRS  252000 non-null  int64
#  12  Risk_Flag          252000 non-null  int64
# dtypes: int64(7), object(6)
# memory usage: 25.0+ MB

# %%
test_data.shape
# Out:
# (28000, 12)

# %%
sample_data = pd.read_csv('./Dataset/Sample Prediction Dataset.csv')
sample_data.head()
# Out:
#    id  risk_flag
# 0   1          0
# 1   2          0
# 2   3          1
# 3   4          0
# 4   5          0

# %% [markdown]
# # Merging the dataset
# Since we have received our data in three different file, we can merge our data into a single file and work on it.

# %%
# Renaming columns in the test dataset
test_data.rename(columns = {'ID':'Id'}, inplace = True)

# Adding predicted risk flags from the sample prediction dataset
test_data['Risk_Flag']=sample_data['risk_flag']

# Concatenating training and test datasets
dataset = pd.concat([training_data, test_data], axis = 0, )

# %%
# Dropping the 'Id' column from the dataset
dataset.drop(['Id'], axis = 1, inplace = True)

# Adding a new 'Id' column with a range of values
dataset.insert(0, "Id", np.arange(0,280000))

# Setting the 'Id' column as the index
dataset.set_index('Id', inplace=True)

# %%
# Replace spaces with underscores in the 'Profession' columns
dataset['Profession'] = dataset['Profession'].apply(lambda x: x.replace(' ', '_'))

# Dropping the 'CITY' and 'STATE' Column from the dataset
dataset.drop(['CITY', 'STATE'], axis=1, inplace=True)

# %%
dataset.head()
# Out:
#      Income  Age  Experience Married/Single House_Ownership Car_Ownership  \
# Id
# 0   1303834   23           3         single          rented            no
# 1   7574516   40          10         single          rented            no
# 2   3991815   66           4        married          rented            no
# 3   6256451   41           2         single          rented           yes
# 4   5768871   47          11         single          rented            no
#
#              Profession  CURRENT_JOB_YRS  CURRENT_HOUSE_YRS  Risk_Flag
# Id
# 0   Mechanical_engineer                3                 13          0
# 1    Software_Developer                9                 13          0
# 2      Technical_writer                4                 10          0
# 3    Software_Developer                2                 12          1
# 4         Civil_servant                3                 14          1

# %%
dataset.shape
# Out:
# (280000, 10)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 280000 entries, 0 to 279999
# Data columns (total 10 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Income             280000 non-null  int64
#  1   Age                280000 non-null  int64
#  2   Experience         280000 non-null  int64
#  3   Married/Single     280000 non-null  object
#  4   House_Ownership    280000 non-null  object
#  5   Car_Ownership      280000 non-null  object
#  6   Profession         280000 non-null  object
#  7   CURRENT_JOB_YRS    280000 non-null  int64
#  8   CURRENT_HOUSE_YRS  280000 non-null  int64
#  9   Risk_Flag          280000 non-null  int64
# dtypes: int64(6), object(4)
# memory usage: 22.4+ MB

# %%
dataset.describe()
# Out:
#              Income            Age     Experience  CURRENT_JOB_YRS  \
# count  2.800000e+05  280000.000000  280000.000000    280000.000000
# mean   5.000361e+06      49.964132      10.088032         6.334418
# std    2.876988e+06      17.070465       6.005066         3.646864
# min    1.031000e+04      21.000000       0.000000         0.000000
# 25%    2.506726e+06      35.000000       5.000000         3.000000
# 50%    5.003310e+06      50.000000      10.000000         6.000000
# 75%    7.477502e+06      65.000000      15.000000         9.000000
# max    9.999938e+06      79.000000      20.000000        14.000000
#
#        CURRENT_HOUSE_YRS      Risk_Flag
# count      280000.000000  280000.000000
# mean           11.997193       0.123532
# std             1.398907       0.329048
# min            10.000000       0.000000
# 25%            11.000000       0.000000
# 50%            12.000000       0.000000
# 75%            13.000000       0.000000
# max            14.000000       1.000000

# %% [markdown]
# # Saving the file
# We can save our merged file for later use.

# %%
dataset.to_csv('./Dataset/Merged_Dataset.csv', index=False)

# %% [markdown]
# # 3. Exploratory Data Analysis (EDA) and Data preprocessing
# Lets check how many are defaulted on loan(Risk_Flag = 1) and how many paid?

# %%
defaulted = dataset['Risk_Flag'].sum()
total = dataset.shape[0]
print(f"The rate of people who defaulted is {defaulted/total * 100:.2f}%")
print(f"The rate of people who paid their loan is {(total - defaulted)/total * 100:.2f}%")
# Out:
# The rate of people who defaulted is 12.35%
# The rate of people who paid their loan is 87.65%

# %%
fig, (ax0, ax1) = plt.subplots(nrows= 1, ncols= 2, figsize = (20,8))

dataset['Risk_Flag'].value_counts().plot.pie(autopct = "%1.1f%%", ax = ax0)
ax0.set_title('Paid vs Defaulted', fontsize = 18, fontweight = 'bold')
ax0.set_ylabel('Risk_Flag',fontsize = 13)

dataset['Risk_Flag'].value_counts().plot(kind = 'bar', ax = ax1, color = ['steelBlue', 'DarkOrange'])
ax1.set_title('Paid vs Defaulted', fontsize = 18, fontweight = 'bold')
ax1.set_xlabel('Risk_Flag', fontsize = 13);

# %% [markdown]
# From above we can see that our 12.4% are defaulted and 87.6% are paid their loan.

# %% [markdown]
# # Correlation Between Features
# Lets check if there is any correlation between the features

# %%
# Separate categorical and numerical columns
categorical_columns = [col for col in dataset.columns if dataset[col].dtype == 'object']
numerical_columns = [col for col in dataset.columns if col not in categorical_columns]

# %%
# Calculate the correlation matrix for numerical columns
numerical_corr_matrix = dataset[numerical_columns].corr()

# Select the column corresponding to the target variable
target_corr = numerical_corr_matrix['Risk_Flag']

# Sort the correlations in descending order
sorted_correlations = target_corr.abs().sort_values(ascending=False)

# Print the top 10 most correlated features
print(sorted_correlations.head(10))
# Out:
# Risk_Flag            1.000000
# Experience           0.029902
# Age                  0.019074
# CURRENT_JOB_YRS      0.013923
# CURRENT_HOUSE_YRS    0.003599
# Income               0.002270
# Name: Risk_Flag, dtype: float64

# %%
# Create the heatmap for numerical correlations
plt.figure(figsize=(10, 8))
sns.heatmap(numerical_corr_matrix, linewidths=0.2, annot=True, cmap='Blues')
plt.title('Correlation Heatmap for Numerical Features')
plt.show()

# %% [markdown]
# From above heatmap, we can see that `CURRENT_JOB_YRS` and `Experiece` has positive correlation.
# We can either merge two feature or remove either one of them. We are removing `Experience` feature beacuse to predict on present context, `CURRENT_JOB_YRS` is more important.

# %%
dataset = dataset.drop('Experience', axis = 1)

# %% [markdown]
# # Income

# %%
dataset['Income'].describe().astype('int64')
# Out:
# count     280000
# mean     5000361
# std      2876987
# min        10310
# 25%      2506726
# 50%      5003310
# 75%      7477502
# max      9999938
# Name: Income, dtype: int64

# %%
fig, ax = plt.subplots(figsize = (8,5))
sns.boxplot(data = dataset['Income'], ax = ax, orient='h');
ax.set_title('Boxplot for Income');

# %% [markdown]
# There is no outlier in our `Income` column.

# %%
Income_range = pd.qcut(dataset['Income'], 4).unique()
Income_range
# Out:
# [(10309.999, 2506726.0], (7477502.0, 9999938.0], (2506726.0, 5003310.0], (5003310.0, 7477502.0]]
# Categories (4, interval[float64, right]): [(10309.999, 2506726.0] < (2506726.0, 5003310.0] < (5003310.0, 7477502.0] < (7477502.0, 9999938.0]]

# %%
bins = [10309, 2506726, 5003310, 7477502, 9999938]
labels = [0,1,2,3]

dataset['Cat_Income'] = pd.cut(dataset['Income'], labels = labels, bins = bins).astype('int64')
dataset = dataset.drop('Income', axis = 1)

# %%
fig, ax = plt.subplots(figsize = (5,5))
dataset['Cat_Income'].value_counts(sort=False).plot.bar(ax = ax, label = 'Cat_Income')
dataset.groupby('Cat_Income')['Risk_Flag'].sum().plot.bar(ax = ax,color = 'DarkOrange', label = 'Risk_Flag')

ax.legend()
ax.set_title('Categorical Income')
ax.set_xlabel('Category/Risk_Flag')
ax.set_ylabel('Value_Count')

sns.catplot(x='Cat_Income', y = 'Risk_Flag', data = dataset, kind = 'point');

# %%
pd.crosstab(dataset['Cat_Income'], dataset['Risk_Flag'], margins=True)
# Out:
# Risk_Flag        0      1     All
# Cat_Income
# 0            61024   8995   70019
# 1            61671   8334   70005
# 2            61605   8396   70001
# 3            61111   8864   69975
# All         245411  34589  280000

# %%
print(f'The rate of people defaulted on loan on each category with corresponding values are: ')
print(f'O : {8995/70019*100:.2f}% (8995)')
print(f'1 : {8334/70005*100:.2f}% (8334)')
print(f'2 : {8396/70001*100:.2f}% (8396)')
print(f'3 : {8864/69975*100:.2f}% (8864)')
# Out:
# The rate of people defaulted on loan on each category with corresponding values are:
# O : 12.85% (8995)
# 1 : 11.90% (8334)
# 2 : 11.99% (8396)
# 3 : 12.67% (8864)

# %% [markdown]
# From the above, we can conclude that the "category 0" has a greater chance of defaulting on its loan. However, people with high incomes are also not repaying their loans, raising the possibility of fraud. There are also other factors we have to check before reaching this conclusion.

# %%
dataset.isna().sum()
# Out:
# Age                  0
# Married/Single       0
# House_Ownership      0
# Car_Ownership        0
# Profession           0
# CURRENT_JOB_YRS      0
# CURRENT_HOUSE_YRS    0
# Risk_Flag            0
# Cat_Income           0
# dtype: int64

# %% [markdown]
# # Age

# %%
dataset['Age'].describe()
# Out:
# count    280000.000000
# mean         49.964132
# std          17.070465
# min          21.000000
# 25%          35.000000
# 50%          50.000000
# 75%          65.000000
# max          79.000000
# Name: Age, dtype: float64

# %%
fig, (ax0, ax1) = plt.subplots(nrows = 1, ncols= 2, figsize = (20,8))
sns.boxplot(data = dataset['Age'], ax = ax0, orient='h')
sns.distplot(dataset['Age'], ax = ax1)

ax0.set_title('Boxplot for Age');
ax1.set_title('Distribution plot for Age');

# %% [markdown]
# There is no outlier in Age. There is no outlier in this age. And the age groups are almost uniformly distributed. Lets change our age group into smaller categorical group.

# %%
Age_range = pd.qcut(dataset['Age'], 5).unique()
Age_range
# Out:
# [(20.999, 32.0], (32.0, 44.0], (56.0, 68.0], (44.0, 56.0], (68.0, 79.0]]
# Categories (5, interval[float64, right]): [(20.999, 32.0] < (32.0, 44.0] < (44.0, 56.0] < (56.0, 68.0] < (68.0, 79.0]]

# %%
bins = [20,32,44,56,68,79]
labels = [0,1,2,3,4]

dataset['Cat_Age'] = pd.cut(dataset['Age'], labels = labels, bins = bins).astype('int64')
dataset = dataset.drop('Age', axis = 1)

# %%
sns.catplot(x='Cat_Age', y = 'Risk_Flag', data = dataset, kind = 'point');

# %%
sns.catplot(data = dataset, x = 'Cat_Age', y = 'Cat_Income',hue = 'Risk_Flag', kind='point')
sns.catplot(data = dataset, x = 'Cat_Income', y = 'Cat_Age',hue = 'Risk_Flag', kind='point');

# %% [markdown]
# From the above graph, we can conclude that the age groups in the lower category are more risky to give loans to.

# %% [markdown]
# # Married/Single

# %%
dataset['Married/Single'].value_counts()
# Out:
# Married/Single
# single     251442
# married     28558
# Name: count, dtype: int64

# %%
pd.crosstab(dataset['Married/Single'], dataset['Risk_Flag'], margins=True)
# Out:
# Risk_Flag            0      1     All
# Married/Single
# married          25548   3010   28558
# single          219863  31579  251442
# All             245411  34589  280000

# %%
print(f'The rate of people defaulted on loan on each category with corresponding values are: ')
print(f'Married : {3010/28558*100:.2f}% (3010)')
print(f'Single : {31579/251442*100:.2f}% (31579)')
# Out:
# The rate of people defaulted on loan on each category with corresponding values are:
# Married : 10.54% (3010)
# Single : 12.56% (31579)

# %%
sns.countplot(data=dataset, x = 'Married/Single', hue = 'Risk_Flag').set(title = 'Paid and Defaulted on Mrried/Single');

# %% [markdown]
# From the above information, we can conclude that single people have more chances of defaulting on a loan.

# %% [markdown]
# # House_Ownership

# %%
dataset['House_Ownership'].value_counts()
# Out:
# House_Ownership
# rented          257703
# owned            14348
# norent_noown      7949
# Name: count, dtype: int64

# %%
sns.countplot(data = dataset, x='House_Ownership', hue = 'Risk_Flag');

# %%
sns.catplot(x='House_Ownership', y = 'Risk_Flag', data = dataset, kind = 'point').set(title = 'Categorical Plot for House_Ownership and Risk_Flag');

# %% [markdown]
# From the above bar graph and categorical plot, people on rent tend to take more loans, and they are also highly likely to default.

# %% [markdown]
# # Car_Ownership

# %%
dataset['Car_Ownership'].value_counts()
# Out:
# Car_Ownership
# no     195625
# yes     84375
# Name: count, dtype: int64

# %%
sns.countplot(data = dataset, x = 'Car_Ownership', hue = 'Risk_Flag');

# %%
sns.catplot(data = dataset, x = 'Car_Ownership', y = 'Risk_Flag', kind='point');

# %% [markdown]
# We can see that the number of people who do not own a car is high, and they are also more likely to default on their loans. Let's check for both car and house ownership to be clear.

# %%
sns.catplot(data = dataset, x = 'House_Ownership', y = 'Risk_Flag',hue = 'Car_Ownership', kind='point')
sns.catplot(data = dataset, x = 'Cat_Income', y = 'Risk_Flag',hue = 'House_Ownership', kind='point');

# %% [markdown]
# From the above graph, we can conclude that rich people who own both a car and a house are less likely to default, and vice versa.

# %% [markdown]
# # Profession

# %%
print(f'The total number of unique professions in dataset is {len(dataset.Profession.unique())}.')
# Out:
# The total number of unique professions in dataset is 51.

# %%
fig, ax = plt.subplots(figsize = (20,8))
dataset['Profession'].value_counts().plot.bar();

# %%
pd.crosstab(dataset['Profession'], dataset['Risk_Flag'], margins = True).sort_values(by=1, ascending=False).head()
# Out:
# Risk_Flag                    0      1     All
# Profession
# All                     245411  34589  280000
# Police_officer            4655    896    5551
# Software_Developer        4753    829    5582
# Air_traffic_controller    5069    786    5855
# Army_officer              4376    786    5162

# %% [markdown]
# From the above information, physicians apply for loans more than other professions, and police officers are the most likely to have defaulted on their loans.

# %% [markdown]
# # Current Job Year

# %%
pd.crosstab(dataset['Risk_Flag'], dataset['CURRENT_JOB_YRS'])
# Out:
# CURRENT_JOB_YRS     0      1      2      3      4      5      6      7   \
# Risk_Flag
# 0                10579  10881  10263  28913  27843  24544  22858  19594
# 1                 1713   1960   2069   3794   3599   3341   3210   2624
#
# CURRENT_JOB_YRS     8      9      10     11     12    13    14
# Risk_Flag
# 0                18492  16949  15433  13117  10461  8732  6752
# 1                 2438   2131   2106   2023   1255  1406   920

# %%
sns.catplot(data = dataset, x = 'CURRENT_JOB_YRS', y = 'Risk_Flag', kind = 'point');

# %% [markdown]
# From the above plot, we can say that when people just started working, they were not able to pay their loan and defaulted, but after a certain amount of time (3 years), many people were able to pay their loan and the default rate decreased.

# %% [markdown]
# # Current House Year

# %%
pd.crosstab(dataset['Risk_Flag'], dataset['CURRENT_HOUSE_YRS'])
# Out:
# CURRENT_HOUSE_YRS     10     11     12     13     14
# Risk_Flag
# 0                  47350  50363  50633  49292  47773
# 1                   6770   7229   7022   6928   6640

# %%
sns.catplot(data = dataset, x = 'CURRENT_HOUSE_YRS', y = 'Risk_Flag', kind = 'point');

# %% [markdown]
# From the above graph, we can conclude that loans are only given to those who have lived in the same residence for more than 10 years, and the default rate decreases as the number of current house years decreases.

# %% [markdown]
# # Converting categorical columns to numerical
# We converted each categorical column to numerical column and also saved label encoder object for each feature for deploy part.

# %%
import os
from pickle import dump

# Create the 'Models' directory if it doesn't exist
models_dir = './Models'
os.makedirs(models_dir, exist_ok=True)

# Rest of code to create and save encoders
categorical_columns = [i for i in dataset.columns if dataset[i].dtype == 'object']
encoders = {}

for column in categorical_columns:
    encoder = LabelEncoder()
    encoder.fit(dataset[column])
    encoders[column] = encoder

with open(os.path.join(models_dir, 'encoders.pkl'), 'wb') as file:
    dump(encoders, file)

for column in categorical_columns:
    label_encoder = encoders[column]
    dataset[column] = label_encoder.transform(dataset[column])

# %%
dataset.head()
# Out:
#     Married/Single  House_Ownership  Car_Ownership  Profession  \
# Id
# 0                1                2              0          33
# 1                1                2              0          43
# 2                0                2              0          47
# 3                1                2              1          43
# 4                1                2              0          11
#
#     CURRENT_JOB_YRS  CURRENT_HOUSE_YRS  Risk_Flag  Cat_Income  Cat_Age
# Id
# 0                 3                 13          0           0        0
# 1                 9                 13          0           3        1
# 2                 4                 10          0           1        3
# 3                 2                 12          1           2        1
# 4                 3                 14          1           2        2

# %% [markdown]
# # Checking correlation of the final dataset

# %%
fig, ax = plt.subplots(figsize = (8,8))
sns.heatmap(dataset.corr(), linewidths=0.2, cmap='Blues', annot=True, ax = ax);

# %% [markdown]
# There is no correlation between features in our dataset. We can now proceed to the next step.

# %% [markdown]
# # 4. Balancing our dataset
# As we've seen earlier, our dataset is not balanced. It contain only **12.4%** on defaulted and **87.4%** on not defaulted.
# Balancing a dataset is important to prevent biases and improve the overall accuracy and generalization ability of machine learning models.
# There are different ways to handle imbalanced dataset:
# * OverSampling
# * UnderSampling
# * Combination of Oversampling and undersampling
# * Ensemble
# * Batching
#
# We are using combination of both oversampling and undersampling technique `(SMOTEENN)` to balance our dataset.
# `SMOTEENN` is a method for balancing imbalanced datasets that combines the oversampling technique `SMOTE (Synthetic Minority Over-sampling Technique)` and the undersampling technique `Edited Nearest Neighbors (ENN)`.

# %%
X = dataset.drop('Risk_Flag', axis = 1)
y = dataset['Risk_Flag']

SMOTEENN = imblearn.combine.SMOTEENN()

print(f'Original dataset shape is {y.shape[0]}')

#X_res, y_res = SMOTEENN.fit_resample(X, y)

#X_res.to_csv('./Dataset/balanced_feature.csv', index=False)
#y_res.to_csv('./Dataset/balanced_target.csv', index=False)

X_res = pd.read_csv('./Dataset/balanced_feature.csv')
y_res = pd.read_csv('./Dataset/balanced_target.csv')

print(f'After undersample dataset shape is {y_res.shape[0]}')
# Out:
# Original dataset shape is 280000
# After undersample dataset shape is 321073

# %%
fig, (ax0, ax1) = plt.subplots(nrows= 1, ncols= 2, figsize = (20,8))

y_res.value_counts().plot.pie(autopct = "%1.1f%%", ax = ax0)
ax0.set_title('Paid vs Defaulted', fontsize = 18, fontweight = 'bold')
ax0.set_ylabel('',fontsize = 13)

y_res.value_counts().plot(kind = 'bar', ax = ax1, color = ['steelBlue', 'DarkOrange'])
ax1.set_title('Paid vs Defaulted', fontsize = 18, fontweight = 'bold');

# %% [markdown]
# Although our data is not balanced, we can work on it better than the previous dataset.

# %% [markdown]
# # 5. Model Training and Testing
# Also, let's create function to evaluate the model.

# %%
def evaluate_preds(y_true, y_preds):
    """
    Performs evaluation comparision on y_true labels vs. y_preds labels on classification.
    """
    accuracy = metrics.accuracy_score(y_true, y_preds)
    precision = metrics.precision_score(y_true, y_preds)
    recall = metrics.recall_score(y_true, y_preds)
    f1 = metrics.f1_score(y_true, y_preds)
    metric_dict = {'accuracy':round(accuracy, 2),
                   'precision':round(precision, 2),
                   'recall':round(recall, 2),
                   'f1':round(f1, 2)}
    print(f'Accuracy : {accuracy * 100:.2f}%')
    print(f'Precision : {precision:.2f}')
    print(f'Recall : {recall:.2f}')
    print(f'F1 score : {f1:.2f}')
    
    return metric_dict

# %%
X_train, X_test, y_train, y_test = train_test_split(X_res, y_res, test_size=0.2, stratify=y_res, random_state=42)

# %% [markdown]
# # 5.1. Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

with mlflow.start_run(run_name="decisiontree"):
    decisiontree = DecisionTreeClassifier(random_state=10)
    decisiontree.fit(X_train, y_train)

    y_pred = decisiontree.predict(X_test)
    result = evaluate_preds(y_test, y_pred)

    cross_val_scores = cross_val_score(decisiontree, X_res, y_res, cv=5, scoring='accuracy')
    print(f'Cross-Validation score: {np.mean(cross_val_scores)*100:.2f}')
    
    mlflow.log_param("random_state", 10)
    mlflow.log_metric("accuracy", result['accuracy'])
    mlflow.log_metric("precision", result['precision'])
    mlflow.log_metric("recall", result['recall'])
    mlflow.log_metric("f1-score", result['f1'])
    mlflow.sklearn.log_model(decisiontree, "model")
    mlflow.sklearn.save_model(decisiontree, "./Models/decisiontree")
# Out:
# Accuracy : 98.81%
# Precision : 0.97
# Recall : 0.99
# F1 score : 0.98
# Cross-Validation score: 97.32

# %%
print(f'The accuracy of Decision Tree on Train_set is {metrics.accuracy_score(y_train, decisiontree.predict(X_train))*100:.2f}%.')
print(f'The accuracy of Decision Tree on Test_set is {metrics.accuracy_score(y_test, decisiontree.predict(X_test))*100:.2f}%.')
# Out:
# The accuracy of Decision Tree on Train_set is 100.00%.
# The accuracy of Decision Tree on Test_set is 98.81%.

# %% [markdown]
# # 5.2. Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

with mlflow.start_run(run_name="randomforest"):
    randomforest = RandomForestClassifier(random_state=10)
    randomforest.fit(X_train, y_train)

    y_pred = randomforest.predict(X_test)
    result = evaluate_preds(y_test, y_pred);

    cross_val_scores = cross_val_score(randomforest, X_res, y_res, cv=5, scoring='accuracy')
    print(f'Cross-Validation score: {np.mean(cross_val_scores)*100:.2f}')
    
    mlflow.log_param("random_state", 10)
    mlflow.log_metric("accuracy", result['accuracy'])
    mlflow.log_metric("precision", result['precision'])
    mlflow.log_metric("recall", result['recall'])
    mlflow.log_metric("f1-score", result['f1'])
    mlflow.sklearn.log_model(randomforest, "model")
    mlflow.sklearn.save_model(randomforest, "./Models/randomforest")
# Out:
# Accuracy : 98.97%
# Precision : 0.98
# Recall : 0.99
# F1 score : 0.99
# Cross-Validation score: 97.27

# %%
print(f'The accuracy of Random Forest on Train_set is {metrics.accuracy_score(y_train, randomforest.predict(X_train))*100:.2f}%.')
print(f'The accuracy of Random Forest on Test_set is {metrics.accuracy_score(y_test, randomforest.predict(X_test))*100:.2f}%.')
# Out:
# The accuracy of Random Forest on Train_set is 100.00%.
# The accuracy of Random Forest on Test_set is 98.97%.

# %% [markdown]
# # 5.3. XGBoost

# %%
from xgboost import XGBClassifier

with mlflow.start_run(run_name="xgb"):
    xgb = XGBClassifier()
    xgb.fit(X_train, y_train)

    y_pred = xgb.predict(X_test)
    result = evaluate_preds(y_test, y_pred);

    cross_val_scores = cross_val_score(xgb, X_res, y_res, cv=5, scoring='accuracy')
    print(f'Cross-Validation score: {np.mean(cross_val_scores)*100:.2f}')
    
    mlflow.log_param("random_state", 10)
    mlflow.log_metric("accuracy", result['accuracy'])
    mlflow.log_metric("precision", result['precision'])
    mlflow.log_metric("recall", result['recall'])
    mlflow.log_metric("f1-score", result['f1'])
    mlflow.sklearn.log_model(xgb, "model")
    mlflow.sklearn.save_model(xgb, "./Models/xgb")
# Out:
# Accuracy : 89.02%
# Precision : 0.92
# Recall : 0.76
# F1 score : 0.83
# Cross-Validation score: 88.85

# %%
print(f'The accuracy of XGBoost on Train_set is {metrics.accuracy_score(y_train, xgb.predict(X_train))*100:.2f}%.')
print(f'The accuracy of XGboost on Test_set is {metrics.accuracy_score(y_test, xgb.predict(X_test))*100:.2f}%.')
# Out:
# The accuracy of XGBoost on Train_set is 89.37%.
# The accuracy of XGboost on Test_set is 89.02%.

# %% [markdown]
# # 5.4. Gradient Boosting

# %%
from sklearn.ensemble import GradientBoostingClassifier

with mlflow.start_run(run_name="gradientboosting"):
    gradientboosting = GradientBoostingClassifier(random_state=10)
    gradientboosting.fit(X_train, y_train)

    y_pred = gradientboosting.predict(X_test)
    result = evaluate_preds(y_test, y_pred);

    cross_val_scores = cross_val_score(gradientboosting, X_res, y_res, cv=5, scoring='accuracy')
    print(f'Cross-Validation score: {np.mean(cross_val_scores)*100:.2f}')
    
    mlflow.log_param("random_state", 10)
    mlflow.log_metric("accuracy", result['accuracy'])
    mlflow.log_metric("precision", result['precision'])
    mlflow.log_metric("recall", result['recall'])
    mlflow.log_metric("f1-score", result['f1'])
    mlflow.sklearn.log_model(gradientboosting, "model")
    mlflow.sklearn.save_model(gradientboosting, "./Models/gradientboosting")
# Out:
# Accuracy : 68.04%
# Precision : 0.64
# Recall : 0.23
# F1 score : 0.34
# Cross-Validation score: 68.27

# %%
print(f'The accuracy of Gradient Boosting on Train_set is {metrics.accuracy_score(y_train, gradientboosting.predict(X_train))*100:.2f}%.')
print(f'The accuracy of Gradient Boosting on Test_set is {metrics.accuracy_score(y_test, gradientboosting.predict(X_test))*100:.2f}%.')
# Out:
# The accuracy of Gradient Boosting on Train_set is 68.09%.
# The accuracy of Gradient Boosting on Test_set is 68.04%.

# %% [markdown]
# # 5.5. Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
import mlflow
import mlflow.sklearn

with mlflow.start_run(run_name="logistic_regression"):
    logistic_regression = LogisticRegression(random_state=10)
    logistic_regression.fit(X_train, y_train)

    y_pred = logistic_regression.predict(X_test)
    result = evaluate_preds(y_test, y_pred)

    cross_val_scores = cross_val_score(logistic_regression, X_res, y_res, cv=5, scoring='accuracy')
    print(f'Cross-Validation score: {np.mean(cross_val_scores)*100:.2f}')
    
    mlflow.log_param("random_state", 10)
    mlflow.log_metric("accuracy", result['accuracy'])
    mlflow.log_metric("precision", result['precision'])
    mlflow.log_metric("recall", result['recall'])
    mlflow.log_metric("f1-score", result['f1'])
    mlflow.sklearn.log_model(logistic_regression, "model")
    mlflow.sklearn.save_model(logistic_regression, "./Models/logistic_regression")
# Out:
# Accuracy : 64.54%
# Precision : 0.50
# Recall : 0.10
# F1 score : 0.16
# Cross-Validation score: 64.46

# %%
print(f'The accuracy of Logistic Regression on Train_set is {metrics.accuracy_score(y_train, logistic_regression.predict(X_train))*100:.2f}%.')
print(f'The accuracy of Logistic Regression on Test_set is {metrics.accuracy_score(y_test, y_pred)*100:.2f}%.')
# Out:
# The accuracy of Logistic Regression on Train_set is 64.37%.
# The accuracy of Logistic Regression on Test_set is 64.54%.

# %% [markdown]
# From the above 5 models, we found that Decision Tree and RandomForest is working good but they seems to be overfitting. Logistic Regression and Gradient Boosting is not giving the good result. XGBoost is giving a good result but with a less recall.

# %% [markdown]
# # 6. Hyperparameter Tuning
# The next step is to hyperparameter tuning. We can hyperparameter tune two models from above: Random Forest and XGBoost.

# %% [markdown]
# **Hyperparameter tuning Random Forest**

# %%
grid = {
    'n_estimators': [50, 80, 100],
    'max_features': ['sqrt', 'log2'],
    'max_depth': [30, 40, 50, 60, 70, 80, 90, 100],
    'min_samples_split': [2, 5]
}


with mlflow.start_run(run_name="final_randomforest"):
    gd = GridSearchCV(estimator=randomforest, param_grid=grid, cv = 5, verbose=2)
    gd.fit(X_train, y_train)
    best_param = gd.best_params_
    print(best_param)
    
    final_randomforest = gd.best_estimator_
    y_pred = final_randomforest.predict(X_test)

    result = evaluate_preds(y_test, y_pred);
    
    for param in best_param:
        mlflow.log_param(param, best_param[param])
    mlflow.log_metric("accuracy", result['accuracy'])
    mlflow.log_metric("precision", result['precision'])
    mlflow.log_metric("recall", result['recall'])
    mlflow.log_metric("f1-score", result['f1'])
    mlflow.sklearn.log_model(final_randomforest, "model")
    mlflow.sklearn.save_model(final_randomforest, "./Models/final_randomforest")
# Out:
# Fitting 5 folds for each of 96 candidates, totalling 480 fits
# [CV] END max_depth=30, max_features=sqrt, min_samples_split=2, n_estimators=50; total time=   6.7s
# [CV] END max_depth=30, max_features=sqrt, min_samples_split=2, n_estimators=50; total time=   7.0s
# [CV] END max_depth=30, max_features=sqrt, min_samples_split=2, n_estimators=50; total time=   6.6s
# [CV] END max_depth=30, max_features=sqrt, min_samples_split=2, n_estimators=50; total time=   6.9s
# [CV] END max_depth=30, max_features=sqrt, min_samples_split=2, n_estimators=50; total time=   6.5s
# [CV] END max_depth=30, max_features=sqrt, min_samples_split=2, n_estimators=80; total time=  10.3s
# [CV] END max_depth=30, max_features=sqrt, min_samples_split=2, n_estimators=80; total time=  10.2s
# [CV] END max_depth=30, max_features=sqrt, min_samples_split=2, n_estimators=80; total time=  10.1s
# [CV] END max_depth=30, max_features=sqrt, min_samples_split=2, n_estimators=80; total time=  10.1s
# [CV] END max_depth=30, max_features=sqrt, min_samples_split=2, n_estimators=80; total time=  10.4s
# [CV] END max_depth=30, max_features=sqrt, min_samples_split=2, n_estimators=100; total time=  13.3s
# [CV] END max_depth=30, max_features=sqrt, min_samples_split=2, n_estimators=100; total time=  14.8s
# [CV] END max_depth=30, max_features=sqrt, min_samples_split=2, n_estimators=100; total time=  13.2s
# [CV] END max_depth=30, max_features=sqrt, min_samples_split=2, n_estimators=100; total time=  13.2s
# [CV] END max_depth=30, max_features=sqrt, min_samples_split=2, n_estimators=100; total time=  13.4s
# [CV] END max_depth=30, max_features=sqrt, min_samples_split=5, n_estimators=50; total time=   6.8s
# [CV] END max_depth=30, max_features=sqrt, min_samples_split=5, n_estimators=50; total time=   6.9s
# [CV] END max_depth=30, max_features=sqrt, min_samples_split=5, n_estimators=50; total time=   7.0s
# [CV] END max_depth=30, max_features=sqrt, min_samples_split=5, n_estimators=50; total time=   6.4s
# [CV] END max_depth=30, max_features=sqrt, min_samples_split=5, n_estimators=50; total time=   6.7s
# [CV] END max_depth=30, max_features=sqrt, min_samples_split=5, n_estimators=80; total time=  10.2s
# [CV] END max_depth=30, max_features=sqrt, min_samples_split=5, n_estimators=80; total time=  10.0s
# [CV] END max_depth=30, max_features=sqrt, min_samples_split=5, n_estimators=80; total time=  10.2s
# [CV] END max_depth=30, max_features=sqrt, min_samples_split=5, n_estimators=80; total time=  10.2s
# [CV] END max_depth=30, max_features=sqrt, min_samples_split=5, n_estimators=80; total time=  10.3s
# [CV] END max_depth=30, max_features=sqrt, min_samples_split=5, n_estimators=100; total time=  13.5s
# [CV] END max_depth=30, max_features=sqrt, min_samples_split=5, n_estimators=100; total time=  13.1s
# [CV] END max_depth=30, max_features=sqrt, min_samples_split=5, n_estimators=100; total time=  13.0s
# [CV] END max_depth=30, max_features=sqrt, min_samples_split=5, n_estimators=100; total time=  12.8s
# [CV] END max_depth=30, max_features=sqrt, min_samples_split=5, n_estimators=100; total time=  13.5s
# [CV] END max_depth=30, max_features=log2, min_samples_split=2, n_estimators=50; total time=   7.5s
# [CV] END max_depth=30, max_features=log2, min_samples_split=2, n_estimators=50; total time=   7.7s
# [CV] END max_depth=30, max_features=log2, min_samples_split=2, n_estimators=50; total time=   8.3s
# [CV] END max_depth=30, max_features=log2, min_samples_split=2, n_estimators=50; total time=   7.8s
# [CV] END max_depth=30, max_features=log2, min_samples_split=2, n_estimators=50; total time=   7.7s
# [CV] END max_depth=30, max_features=log2, min_samples_split=2, n_estimators=80; total time=  12.0s
# [CV] END max_depth=30, max_features=log2, min_samples_split=2, n_estimators=80; total time=  11.7s
# [CV] END max_depth=30, max_features=log2, min_samples_split=2, n_estimators=80; total time=  12.2s
# [CV] END max_depth=30, max_features=log2, min_samples_split=2, n_estimators=80; total time=  12.2s
# [CV] END max_depth=30, max_features=log2, min_samples_split=2, n_estimators=80; total time=  12.1s
# [CV] END max_depth=30, max_features=log2, min_samples_split=2, n_estimators=100; total time=  15.4s
# [CV] END max_depth=30, max_features=log2, min_samples_split=2, n_estimators=100; total time=  15.3s
# [CV] END max_depth=30, max_features=log2, min_samples_split=2, n_estimators=100; total time=  15.2s
# [CV] END max_depth=30, max_features=log2, min_samples_split=2, n_estimators=100; total time=  15.2s
# [CV] END max_depth=30, max_features=log2, min_samples_split=2, n_estimators=100; total time=  15.6s
# [CV] END max_depth=30, max_features=log2, min_samples_split=5, n_estimators=50; total time=   7.7s
# [CV] END max_depth=30, max_features=log2, min_samples_split=5, n_estimators=50; total time=   7.6s
# [CV] END max_depth=30, max_features=log2, min_samples_split=5, n_estimators=50; total time=   7.7s
# [CV] END max_depth=30, max_features=log2, min_samples_split=5, n_estimators=50; total time=   7.4s
# [CV] END max_depth=30, max_features=log2, min_samples_split=5, n_estimators=50; total time=   7.5s
# [CV] END max_depth=30, max_features=log2, min_samples_split=5, n_estimators=80; total time=  11.7s
# [CV] END max_depth=30, max_features=log2, min_samples_split=5, n_estimators=80; total time=  11.8s
# [CV] END max_depth=30, max_features=log2, min_samples_split=5, n_estimators=80; total time=  11.8s
# [CV] END max_depth=30, max_features=log2, min_samples_split=5, n_estimators=80; total time=  12.2s
# [CV] END max_depth=30, max_features=log2, min_samples_split=5, n_estimators=80; total time=  12.2s
# [CV] END max_depth=30, max_features=log2, min_samples_split=5, n_estimators=100; total time=  15.1s
# [CV] END max_depth=30, max_features=log2, min_samples_split=5, n_estimators=100; total time=  15.3s
# [CV] END max_depth=30, max_features=log2, min_samples_split=5, n_estimators=100; total time=  15.8s
# [CV] END max_depth=30, max_features=log2, min_samples_split=5, n_estimators=100; total time=  15.9s
# [CV] END max_depth=30, max_features=log2, min_samples_split=5, n_estimators=100; total time=  17.4s
# [CV] END max_depth=40, max_features=sqrt, min_samples_split=2, n_estimators=50; total time=   6.5s
# [CV] END max_depth=40, max_features=sqrt, min_samples_split=2, n_estimators=50; total time=   6.4s
# [CV] END max_depth=40, max_features=sqrt, min_samples_split=2, n_estimators=50; total time=   6.8s
# [CV] END max_depth=40, max_features=sqrt, min_samples_split=2, n_estimators=50; total time=   6.4s
# [CV] END max_depth=40, max_features=sqrt, min_samples_split=2, n_estimators=50; total time=   6.3s
# [CV] END max_depth=40, max_features=sqrt, min_samples_split=2, n_estimators=80; total time=  10.4s
# [CV] END max_depth=40, max_features=sqrt, min_samples_split=2, n_estimators=80; total time=  10.4s
# [CV] END max_depth=40, max_features=sqrt, min_samples_split=2, n_estimators=80; total time=  11.2s
# [CV] END max_depth=40, max_features=sqrt, min_samples_split=2, n_estimators=80; total time=  11.2s
# [CV] END max_depth=40, max_features=sqrt, min_samples_split=2, n_estimators=80; total time=  10.2s
# [CV] END max_depth=40, max_features=sqrt, min_samples_split=2, n_estimators=100; total time=  13.0s
# [CV] END max_depth=40, max_features=sqrt, min_samples_split=2, n_estimators=100; total time=  13.6s
# [CV] END max_depth=40, max_features=sqrt, min_samples_split=2, n_estimators=100; total time=  13.3s
# [CV] END max_depth=40, max_features=sqrt, min_samples_split=2, n_estimators=100; total time=  14.8s
# [CV] END max_depth=40, max_features=sqrt, min_samples_split=2, n_estimators=100; total time=  14.6s
# [CV] END max_depth=40, max_features=sqrt, min_samples_split=5, n_estimators=50; total time=   6.5s
# [CV] END max_depth=40, max_features=sqrt, min_samples_split=5, n_estimators=50; total time=   6.5s
# [CV] END max_depth=40, max_features=sqrt, min_samples_split=5, n_estimators=50; total time=   6.5s
# [CV] END max_depth=40, max_features=sqrt, min_samples_split=5, n_estimators=50; total time=   6.5s
# [CV] END max_depth=40, max_features=sqrt, min_samples_split=5, n_estimators=50; total time=   6.5s
# [CV] END max_depth=40, max_features=sqrt, min_samples_split=5, n_estimators=80; total time=  10.3s
# [CV] END max_depth=40, max_features=sqrt, min_samples_split=5, n_estimators=80; total time=  10.4s
# [CV] END max_depth=40, max_features=sqrt, min_samples_split=5, n_estimators=80; total time=  10.3s
# [CV] END max_depth=40, max_features=sqrt, min_samples_split=5, n_estimators=80; total time=  10.4s
# [CV] END max_depth=40, max_features=sqrt, min_samples_split=5, n_estimators=80; total time=  11.7s
# [CV] END max_depth=40, max_features=sqrt, min_samples_split=5, n_estimators=100; total time=  14.3s
# [CV] END max_depth=40, max_features=sqrt, min_samples_split=5, n_estimators=100; total time=  13.5s
# [CV] END max_depth=40, max_features=sqrt, min_samples_split=5, n_estimators=100; total time=  12.8s
# [CV] END max_depth=40, max_features=sqrt, min_samples_split=5, n_estimators=100; total time=  13.0s
# [CV] END max_depth=40, max_features=sqrt, min_samples_split=5, n_estimators=100; total time=  13.1s
# [CV] END max_depth=40, max_features=log2, min_samples_split=2, n_estimators=50; total time=   7.6s
# [CV] END max_depth=40, max_features=log2, min_samples_split=2, n_estimators=50; total time=   7.7s
# [CV] END max_depth=40, max_features=log2, min_samples_split=2, n_estimators=50; total time=   7.7s
# [CV] END max_depth=40, max_features=log2, min_samples_split=2, n_estimators=50; total time=   7.7s
# [CV] END max_depth=40, max_features=log2, min_samples_split=2, n_estimators=50; total time=   7.7s
# [CV] END max_depth=40, max_features=log2, min_samples_split=2, n_estimators=80; total time=  12.2s
# [CV] END max_depth=40, max_features=log2, min_samples_split=2, n_estimators=80; total time=  12.3s
# [CV] END max_depth=40, max_features=log2, min_samples_split=2, n_estimators=80; total time=  12.5s
# [CV] END max_depth=40, max_features=log2, min_samples_split=2, n_estimators=80; total time=  12.3s
# [CV] END max_depth=40, max_features=log2, min_samples_split=2, n_estimators=80; total time=  12.4s
# [CV] END max_depth=40, max_features=log2, min_samples_split=2, n_estimators=100; total time=  15.3s
# [CV] END max_depth=40, max_features=log2, min_samples_split=2, n_estimators=100; total time=  15.3s
# [CV] END max_depth=40, max_features=log2, min_samples_split=2, n_estimators=100; total time=  15.3s
# [CV] END max_depth=40, max_features=log2, min_samples_split=2, n_estimators=100; total time=  15.4s
# [CV] END max_depth=40, max_features=log2, min_samples_split=2, n_estimators=100; total time=  15.3s
# [CV] END max_depth=40, max_features=log2, min_samples_split=5, n_estimators=50; total time=   7.5s
# [CV] END max_depth=40, max_features=log2, min_samples_split=5, n_estimators=50; total time=   7.6s
# [CV] END max_depth=40, max_features=log2, min_samples_split=5, n_estimators=50; total time=   7.9s
# [CV] END max_depth=40, max_features=log2, min_samples_split=5, n_estimators=50; total time=   7.6s
# [CV] END max_depth=40, max_features=log2, min_samples_split=5, n_estimators=50; total time=   7.6s
# [CV] END max_depth=40, max_features=log2, min_samples_split=5, n_estimators=80; total time=  12.2s
# [CV] END max_depth=40, max_features=log2, min_samples_split=5, n_estimators=80; total time=  12.2s
# [CV] END max_depth=40, max_features=log2, min_samples_split=5, n_estimators=80; total time=  12.2s
# [CV] END max_depth=40, max_features=log2, min_samples_split=5, n_estimators=80; total time=  12.2s
# [CV] END max_depth=40, max_features=log2, min_samples_split=5, n_estimators=80; total time=  12.1s
# [CV] END max_depth=40, max_features=log2, min_samples_split=5, n_estimators=100; total time=  17.1s
# [CV] END max_depth=40, max_features=log2, min_samples_split=5, n_estimators=100; total time=  16.7s
# [CV] END max_depth=40, max_features=log2, min_samples_split=5, n_estimators=100; total time=  15.2s
# [CV] END max_depth=40, max_features=log2, min_samples_split=5, n_estimators=100; total time=  15.1s
# [CV] END max_depth=40, max_features=log2, min_samples_split=5, n_estimators=100; total time=  15.2s
# [CV] END max_depth=50, max_features=sqrt, min_samples_split=2, n_estimators=50; total time=   6.6s
# [CV] END max_depth=50, max_features=sqrt, min_samples_split=2, n_estimators=50; total time=   6.5s
# [CV] END max_depth=50, max_features=sqrt, min_samples_split=2, n_estimators=50; total time=   6.7s
# [CV] END max_depth=50, max_features=sqrt, min_samples_split=2, n_estimators=50; total time=   6.9s
# [CV] END max_depth=50, max_features=sqrt, min_samples_split=2, n_estimators=50; total time=   6.5s
# [CV] END max_depth=50, max_features=sqrt, min_samples_split=2, n_estimators=80; total time=  10.7s
# [CV] END max_depth=50, max_features=sqrt, min_samples_split=2, n_estimators=80; total time=  10.5s
# [CV] END max_depth=50, max_features=sqrt, min_samples_split=2, n_estimators=80; total time=  10.5s
# [CV] END max_depth=50, max_features=sqrt, min_samples_split=2, n_estimators=80; total time=  10.5s
# [CV] END max_depth=50, max_features=sqrt, min_samples_split=2, n_estimators=80; total time=  10.5s
# [CV] END max_depth=50, max_features=sqrt, min_samples_split=2, n_estimators=100; total time=  13.2s
# [CV] END max_depth=50, max_features=sqrt, min_samples_split=2, n_estimators=100; total time=  13.1s
# [CV] END max_depth=50, max_features=sqrt, min_samples_split=2, n_estimators=100; total time=  13.2s
# [CV] END max_depth=50, max_features=sqrt, min_samples_split=2, n_estimators=100; total time=  12.8s
# [CV] END max_depth=50, max_features=sqrt, min_samples_split=2, n_estimators=100; total time=  13.2s
# [CV] END max_depth=50, max_features=sqrt, min_samples_split=5, n_estimators=50; total time=   6.5s
# [CV] END max_depth=50, max_features=sqrt, min_samples_split=5, n_estimators=50; total time=   6.6s
# [CV] END max_depth=50, max_features=sqrt, min_samples_split=5, n_estimators=50; total time=   6.5s
# [CV] END max_depth=50, max_features=sqrt, min_samples_split=5, n_estimators=50; total time=   6.5s
# [CV] END max_depth=50, max_features=sqrt, min_samples_split=5, n_estimators=50; total time=   6.6s
# [CV] END max_depth=50, max_features=sqrt, min_samples_split=5, n_estimators=80; total time=  10.3s
# [CV] END max_depth=50, max_features=sqrt, min_samples_split=5, n_estimators=80; total time=  10.0s
# [CV] END max_depth=50, max_features=sqrt, min_samples_split=5, n_estimators=80; total time=  10.4s
# [CV] END max_depth=50, max_features=sqrt, min_samples_split=5, n_estimators=80; total time=  10.4s
# [CV] END max_depth=50, max_features=sqrt, min_samples_split=5, n_estimators=80; total time=  10.5s
# [CV] END max_depth=50, max_features=sqrt, min_samples_split=5, n_estimators=100; total time=  12.9s
# [CV] END max_depth=50, max_features=sqrt, min_samples_split=5, n_estimators=100; total time=  14.9s
# [CV] END max_depth=50, max_features=sqrt, min_samples_split=5, n_estimators=100; total time=  13.1s
# [CV] END max_depth=50, max_features=sqrt, min_samples_split=5, n_estimators=100; total time=  13.0s
# [CV] END max_depth=50, max_features=sqrt, min_samples_split=5, n_estimators=100; total time=  13.2s
# [CV] END max_depth=50, max_features=log2, min_samples_split=2, n_estimators=50; total time=   7.6s
# [CV] END max_depth=50, max_features=log2, min_samples_split=2, n_estimators=50; total time=   7.8s
# [CV] END max_depth=50, max_features=log2, min_samples_split=2, n_estimators=50; total time=   7.7s
# [CV] END max_depth=50, max_features=log2, min_samples_split=2, n_estimators=50; total time=   7.7s
# [CV] END max_depth=50, max_features=log2, min_samples_split=2, n_estimators=50; total time=   7.7s
# [CV] END max_depth=50, max_features=log2, min_samples_split=2, n_estimators=80; total time=  12.2s
# [CV] END max_depth=50, max_features=log2, min_samples_split=2, n_estimators=80; total time=  12.2s
# [CV] END max_depth=50, max_features=log2, min_samples_split=2, n_estimators=80; total time=  12.3s
# [CV] END max_depth=50, max_features=log2, min_samples_split=2, n_estimators=80; total time=  12.3s
# [CV] END max_depth=50, max_features=log2, min_samples_split=2, n_estimators=80; total time=  12.3s
# [CV] END max_depth=50, max_features=log2, min_samples_split=2, n_estimators=100; total time=  15.3s
# [CV] END max_depth=50, max_features=log2, min_samples_split=2, n_estimators=100; total time=  15.3s
# [CV] END max_depth=50, max_features=log2, min_samples_split=2, n_estimators=100; total time=  15.4s
# [CV] END max_depth=50, max_features=log2, min_samples_split=2, n_estimators=100; total time=  15.5s
# [CV] END max_depth=50, max_features=log2, min_samples_split=2, n_estimators=100; total time=  15.5s
# [CV] END max_depth=50, max_features=log2, min_samples_split=5, n_estimators=50; total time=   7.6s
# [CV] END max_depth=50, max_features=log2, min_samples_split=5, n_estimators=50; total time=   7.6s
# [CV] END max_depth=50, max_features=log2, min_samples_split=5, n_estimators=50; total time=   7.6s
# [CV] END max_depth=50, max_features=log2, min_samples_split=5, n_estimators=50; total time=   7.7s
# [CV] END max_depth=50, max_features=log2, min_samples_split=5, n_estimators=50; total time=   7.7s
# [CV] END max_depth=50, max_features=log2, min_samples_split=5, n_estimators=80; total time=  12.2s
# [CV] END max_depth=50, max_features=log2, min_samples_split=5, n_estimators=80; total time=  14.9s
# [CV] END max_depth=50, max_features=log2, min_samples_split=5, n_estimators=80; total time=  12.7s
# [CV] END max_depth=50, max_features=log2, min_samples_split=5, n_estimators=80; total time=  12.2s
# [CV] END max_depth=50, max_features=log2, min_samples_split=5, n_estimators=80; total time=  12.2s
# [CV] END max_depth=50, max_features=log2, min_samples_split=5, n_estimators=100; total time=  15.2s
# [CV] END max_depth=50, max_features=log2, min_samples_split=5, n_estimators=100; total time=  15.4s
# [CV] END max_depth=50, max_features=log2, min_samples_split=5, n_estimators=100; total time=  15.3s
# [CV] END max_depth=50, max_features=log2, min_samples_split=5, n_estimators=100; total time=  15.3s
# [CV] END max_depth=50, max_features=log2, min_samples_split=5, n_estimators=100; total time=  15.3s
# [CV] END max_depth=60, max_features=sqrt, min_samples_split=2, n_estimators=50; total time=   6.5s
# [CV] END max_depth=60, max_features=sqrt, min_samples_split=2, n_estimators=50; total time=   6.5s
# [CV] END max_depth=60, max_features=sqrt, min_samples_split=2, n_estimators=50; total time=   6.6s
# [CV] END max_depth=60, max_features=sqrt, min_samples_split=2, n_estimators=50; total time=   6.6s
# [CV] END max_depth=60, max_features=sqrt, min_samples_split=2, n_estimators=50; total time=   7.3s
# [CV] END max_depth=60, max_features=sqrt, min_samples_split=2, n_estimators=80; total time=  10.9s
# [CV] END max_depth=60, max_features=sqrt, min_samples_split=2, n_estimators=80; total time=  10.5s
# [CV] END max_depth=60, max_features=sqrt, min_samples_split=2, n_estimators=80; total time=  10.5s
# [CV] END max_depth=60, max_features=sqrt, min_samples_split=2, n_estimators=80; total time=  10.5s
# [CV] END max_depth=60, max_features=sqrt, min_samples_split=2, n_estimators=80; total time=  10.5s
# [CV] END max_depth=60, max_features=sqrt, min_samples_split=2, n_estimators=100; total time=  13.1s
# [CV] END max_depth=60, max_features=sqrt, min_samples_split=2, n_estimators=100; total time=  13.1s
# [CV] END max_depth=60, max_features=sqrt, min_samples_split=2, n_estimators=100; total time=  13.2s
# [CV] END max_depth=60, max_features=sqrt, min_samples_split=2, n_estimators=100; total time=  13.2s
# [CV] END max_depth=60, max_features=sqrt, min_samples_split=2, n_estimators=100; total time=  13.1s
# [CV] END max_depth=60, max_features=sqrt, min_samples_split=5, n_estimators=50; total time=   6.5s
# [CV] END max_depth=60, max_features=sqrt, min_samples_split=5, n_estimators=50; total time=   6.5s
# [CV] END max_depth=60, max_features=sqrt, min_samples_split=5, n_estimators=50; total time=   6.5s
# [CV] END max_depth=60, max_features=sqrt, min_samples_split=5, n_estimators=50; total time=   6.5s
# [CV] END max_depth=60, max_features=sqrt, min_samples_split=5, n_estimators=50; total time=   6.5s
# [CV] END max_depth=60, max_features=sqrt, min_samples_split=5, n_estimators=80; total time=  10.4s
# [CV] END max_depth=60, max_features=sqrt, min_samples_split=5, n_estimators=80; total time=  11.5s
# [CV] END max_depth=60, max_features=sqrt, min_samples_split=5, n_estimators=80; total time=  11.9s
# [CV] END max_depth=60, max_features=sqrt, min_samples_split=5, n_estimators=80; total time=  10.4s
# [CV] END max_depth=60, max_features=sqrt, min_samples_split=5, n_estimators=80; total time=  11.5s
# [CV] END max_depth=60, max_features=sqrt, min_samples_split=5, n_estimators=100; total time=  13.0s
# [CV] END max_depth=60, max_features=sqrt, min_samples_split=5, n_estimators=100; total time=  13.0s
# [CV] END max_depth=60, max_features=sqrt, min_samples_split=5, n_estimators=100; total time=  13.0s
# [CV] END max_depth=60, max_features=sqrt, min_samples_split=5, n_estimators=100; total time=  13.1s
# [CV] END max_depth=60, max_features=sqrt, min_samples_split=5, n_estimators=100; total time=  13.1s
# [CV] END max_depth=60, max_features=log2, min_samples_split=2, n_estimators=50; total time=   7.6s
# [CV] END max_depth=60, max_features=log2, min_samples_split=2, n_estimators=50; total time=   7.6s
# [CV] END max_depth=60, max_features=log2, min_samples_split=2, n_estimators=50; total time=   7.7s
# [CV] END max_depth=60, max_features=log2, min_samples_split=2, n_estimators=50; total time=   8.2s
# [CV] END max_depth=60, max_features=log2, min_samples_split=2, n_estimators=50; total time=   9.0s
# [CV] END max_depth=60, max_features=log2, min_samples_split=2, n_estimators=80; total time=  13.8s
# [CV] END max_depth=60, max_features=log2, min_samples_split=2, n_estimators=80; total time=  12.7s
# [CV] END max_depth=60, max_features=log2, min_samples_split=2, n_estimators=80; total time=  12.7s
# [CV] END max_depth=60, max_features=log2, min_samples_split=2, n_estimators=80; total time=  12.3s
# [CV] END max_depth=60, max_features=log2, min_samples_split=2, n_estimators=80; total time=  12.3s
# [CV] END max_depth=60, max_features=log2, min_samples_split=2, n_estimators=100; total time=  15.4s
# [CV] END max_depth=60, max_features=log2, min_samples_split=2, n_estimators=100; total time=  15.4s
# [CV] END max_depth=60, max_features=log2, min_samples_split=2, n_estimators=100; total time=  15.5s
# [CV] END max_depth=60, max_features=log2, min_samples_split=2, n_estimators=100; total time=  15.3s
# [CV] END max_depth=60, max_features=log2, min_samples_split=2, n_estimators=100; total time=  15.4s
# [CV] END max_depth=60, max_features=log2, min_samples_split=5, n_estimators=50; total time=   8.5s
# [CV] END max_depth=60, max_features=log2, min_samples_split=5, n_estimators=50; total time=   8.6s
# [CV] END max_depth=60, max_features=log2, min_samples_split=5, n_estimators=50; total time=   7.6s
# [CV] END max_depth=60, max_features=log2, min_samples_split=5, n_estimators=50; total time=   7.6s
# [CV] END max_depth=60, max_features=log2, min_samples_split=5, n_estimators=50; total time=   7.6s
# [CV] END max_depth=60, max_features=log2, min_samples_split=5, n_estimators=80; total time=  14.6s
# [CV] END max_depth=60, max_features=log2, min_samples_split=5, n_estimators=80; total time=  12.3s
# [CV] END max_depth=60, max_features=log2, min_samples_split=5, n_estimators=80; total time=  12.3s
# [CV] END max_depth=60, max_features=log2, min_samples_split=5, n_estimators=80; total time=  12.2s
# [CV] END max_depth=60, max_features=log2, min_samples_split=5, n_estimators=80; total time=  12.1s
# [CV] END max_depth=60, max_features=log2, min_samples_split=5, n_estimators=100; total time=  15.3s
# [CV] END max_depth=60, max_features=log2, min_samples_split=5, n_estimators=100; total time=  15.7s
# [CV] END max_depth=60, max_features=log2, min_samples_split=5, n_estimators=100; total time=  17.7s
# [CV] END max_depth=60, max_features=log2, min_samples_split=5, n_estimators=100; total time=  15.2s
# [CV] END max_depth=60, max_features=log2, min_samples_split=5, n_estimators=100; total time=  15.3s
# [CV] END max_depth=70, max_features=sqrt, min_samples_split=2, n_estimators=50; total time=   6.5s
# [CV] END max_depth=70, max_features=sqrt, min_samples_split=2, n_estimators=50; total time=   6.6s
# [CV] END max_depth=70, max_features=sqrt, min_samples_split=2, n_estimators=50; total time=   6.5s
# [CV] END max_depth=70, max_features=sqrt, min_samples_split=2, n_estimators=50; total time=   6.6s
# [CV] END max_depth=70, max_features=sqrt, min_samples_split=2, n_estimators=50; total time=   6.5s
# [CV] END max_depth=70, max_features=sqrt, min_samples_split=2, n_estimators=80; total time=  10.5s
# [CV] END max_depth=70, max_features=sqrt, min_samples_split=2, n_estimators=80; total time=  10.4s
# [CV] END max_depth=70, max_features=sqrt, min_samples_split=2, n_estimators=80; total time=  10.5s
# [CV] END max_depth=70, max_features=sqrt, min_samples_split=2, n_estimators=80; total time=  10.6s
# [CV] END max_depth=70, max_features=sqrt, min_samples_split=2, n_estimators=80; total time=  10.5s
# [CV] END max_depth=70, max_features=sqrt, min_samples_split=2, n_estimators=100; total time=  13.1s
# [CV] END max_depth=70, max_features=sqrt, min_samples_split=2, n_estimators=100; total time=  13.2s
# [CV] END max_depth=70, max_features=sqrt, min_samples_split=2, n_estimators=100; total time=  13.3s
# [CV] END max_depth=70, max_features=sqrt, min_samples_split=2, n_estimators=100; total time=  13.3s
# [CV] END max_depth=70, max_features=sqrt, min_samples_split=2, n_estimators=100; total time=  13.2s
# [CV] END max_depth=70, max_features=sqrt, min_samples_split=5, n_estimators=50; total time=   6.5s
# [CV] END max_depth=70, max_features=sqrt, min_samples_split=5, n_estimators=50; total time=   6.8s
# [CV] END max_depth=70, max_features=sqrt, min_samples_split=5, n_estimators=50; total time=   6.8s
# [CV] END max_depth=70, max_features=sqrt, min_samples_split=5, n_estimators=50; total time=   6.7s
# [CV] END max_depth=70, max_features=sqrt, min_samples_split=5, n_estimators=50; total time=   6.6s
# [CV] END max_depth=70, max_features=sqrt, min_samples_split=5, n_estimators=80; total time=  10.9s
# [CV] END max_depth=70, max_features=sqrt, min_samples_split=5, n_estimators=80; total time=  12.3s
# [CV] END max_depth=70, max_features=sqrt, min_samples_split=5, n_estimators=80; total time=  11.8s
# [CV] END max_depth=70, max_features=sqrt, min_samples_split=5, n_estimators=80; total time=  12.0s
# [CV] END max_depth=70, max_features=sqrt, min_samples_split=5, n_estimators=80; total time=  12.7s
# [CV] END max_depth=70, max_features=sqrt, min_samples_split=5, n_estimators=100; total time=  15.1s
# [CV] END max_depth=70, max_features=sqrt, min_samples_split=5, n_estimators=100; total time=  15.3s
# [CV] END max_depth=70, max_features=sqrt, min_samples_split=5, n_estimators=100; total time=  15.2s
# [CV] END max_depth=70, max_features=sqrt, min_samples_split=5, n_estimators=100; total time=  15.7s
# [CV] END max_depth=70, max_features=sqrt, min_samples_split=5, n_estimators=100; total time=  15.0s
# [CV] END max_depth=70, max_features=log2, min_samples_split=2, n_estimators=50; total time=   9.2s
# [CV] END max_depth=70, max_features=log2, min_samples_split=2, n_estimators=50; total time=   9.3s
# [CV] END max_depth=70, max_features=log2, min_samples_split=2, n_estimators=50; total time=   9.1s
# [CV] END max_depth=70, max_features=log2, min_samples_split=2, n_estimators=50; total time=   9.3s
# [CV] END max_depth=70, max_features=log2, min_samples_split=2, n_estimators=50; total time=   9.2s
# [CV] END max_depth=70, max_features=log2, min_samples_split=2, n_estimators=80; total time=  13.8s
# [CV] END max_depth=70, max_features=log2, min_samples_split=2, n_estimators=80; total time=  14.6s
# [CV] END max_depth=70, max_features=log2, min_samples_split=2, n_estimators=80; total time=  14.4s
# [CV] END max_depth=70, max_features=log2, min_samples_split=2, n_estimators=80; total time=  12.4s
# [CV] END max_depth=70, max_features=log2, min_samples_split=2, n_estimators=80; total time=  12.3s
# [CV] END max_depth=70, max_features=log2, min_samples_split=2, n_estimators=100; total time=  15.4s
# [CV] END max_depth=70, max_features=log2, min_samples_split=2, n_estimators=100; total time=  15.7s
# [CV] END max_depth=70, max_features=log2, min_samples_split=2, n_estimators=100; total time=  18.8s
# [CV] END max_depth=70, max_features=log2, min_samples_split=2, n_estimators=100; total time=  16.4s
# [CV] END max_depth=70, max_features=log2, min_samples_split=2, n_estimators=100; total time=  14.9s
# [CV] END max_depth=70, max_features=log2, min_samples_split=5, n_estimators=50; total time=   7.4s
# [CV] END max_depth=70, max_features=log2, min_samples_split=5, n_estimators=50; total time=   7.2s
# [CV] END max_depth=70, max_features=log2, min_samples_split=5, n_estimators=50; total time=   7.3s
# [CV] END max_depth=70, max_features=log2, min_samples_split=5, n_estimators=50; total time=   7.4s
# [CV] END max_depth=70, max_features=log2, min_samples_split=5, n_estimators=50; total time=   7.3s
# [CV] END max_depth=70, max_features=log2, min_samples_split=5, n_estimators=80; total time=  11.8s
# [CV] END max_depth=70, max_features=log2, min_samples_split=5, n_estimators=80; total time=  11.7s
# [CV] END max_depth=70, max_features=log2, min_samples_split=5, n_estimators=80; total time=  11.8s
# [CV] END max_depth=70, max_features=log2, min_samples_split=5, n_estimators=80; total time=  11.8s
# [CV] END max_depth=70, max_features=log2, min_samples_split=5, n_estimators=80; total time=  11.7s
# [CV] END max_depth=70, max_features=log2, min_samples_split=5, n_estimators=100; total time=  14.7s
# [CV] END max_depth=70, max_features=log2, min_samples_split=5, n_estimators=100; total time=  14.8s
# [CV] END max_depth=70, max_features=log2, min_samples_split=5, n_estimators=100; total time=  14.7s
# [CV] END max_depth=70, max_features=log2, min_samples_split=5, n_estimators=100; total time=  14.3s
# [CV] END max_depth=70, max_features=log2, min_samples_split=5, n_estimators=100; total time=  15.0s
# [CV] END max_depth=80, max_features=sqrt, min_samples_split=2, n_estimators=50; total time=   6.3s
# [CV] END max_depth=80, max_features=sqrt, min_samples_split=2, n_estimators=50; total time=   6.3s
# [CV] END max_depth=80, max_features=sqrt, min_samples_split=2, n_estimators=50; total time=   6.3s
# [CV] END max_depth=80, max_features=sqrt, min_samples_split=2, n_estimators=50; total time=   6.4s
# [CV] END max_depth=80, max_features=sqrt, min_samples_split=2, n_estimators=50; total time=   6.4s
# [CV] END max_depth=80, max_features=sqrt, min_samples_split=2, n_estimators=80; total time=  10.3s
# [CV] END max_depth=80, max_features=sqrt, min_samples_split=2, n_estimators=80; total time=  10.4s
# [CV] END max_depth=80, max_features=sqrt, min_samples_split=2, n_estimators=80; total time=  12.1s
# [CV] END max_depth=80, max_features=sqrt, min_samples_split=2, n_estimators=80; total time=  11.9s
# [CV] END max_depth=80, max_features=sqrt, min_samples_split=2, n_estimators=80; total time=  14.7s
# [CV] END max_depth=80, max_features=sqrt, min_samples_split=2, n_estimators=100; total time=  13.3s
# [CV] END max_depth=80, max_features=sqrt, min_samples_split=2, n_estimators=100; total time=  13.0s
# [CV] END max_depth=80, max_features=sqrt, min_samples_split=2, n_estimators=100; total time=  13.1s
# [CV] END max_depth=80, max_features=sqrt, min_samples_split=2, n_estimators=100; total time=  13.4s
# [CV] END max_depth=80, max_features=sqrt, min_samples_split=2, n_estimators=100; total time=  15.3s
# [CV] END max_depth=80, max_features=sqrt, min_samples_split=5, n_estimators=50; total time=   6.8s
# [CV] END max_depth=80, max_features=sqrt, min_samples_split=5, n_estimators=50; total time=   8.0s
# [CV] END max_depth=80, max_features=sqrt, min_samples_split=5, n_estimators=50; total time=   7.9s
# [CV] END max_depth=80, max_features=sqrt, min_samples_split=5, n_estimators=50; total time=   7.6s
# [CV] END max_depth=80, max_features=sqrt, min_samples_split=5, n_estimators=50; total time=   6.5s
# [CV] END max_depth=80, max_features=sqrt, min_samples_split=5, n_estimators=80; total time=  10.4s
# [CV] END max_depth=80, max_features=sqrt, min_samples_split=5, n_estimators=80; total time=  10.9s
# [CV] END max_depth=80, max_features=sqrt, min_samples_split=5, n_estimators=80; total time=  10.3s
# [CV] END max_depth=80, max_features=sqrt, min_samples_split=5, n_estimators=80; total time=  10.4s
# [CV] END max_depth=80, max_features=sqrt, min_samples_split=5, n_estimators=80; total time=  10.5s
# [CV] END max_depth=80, max_features=sqrt, min_samples_split=5, n_estimators=100; total time=  14.0s
# [CV] END max_depth=80, max_features=sqrt, min_samples_split=5, n_estimators=100; total time=  12.9s
# [CV] END max_depth=80, max_features=sqrt, min_samples_split=5, n_estimators=100; total time=  13.1s
# [CV] END max_depth=80, max_features=sqrt, min_samples_split=5, n_estimators=100; total time=  12.9s
# [CV] END max_depth=80, max_features=sqrt, min_samples_split=5, n_estimators=100; total time=  12.7s
# [CV] END max_depth=80, max_features=log2, min_samples_split=2, n_estimators=50; total time=   8.7s
# [CV] END max_depth=80, max_features=log2, min_samples_split=2, n_estimators=50; total time=   8.1s
# [CV] END max_depth=80, max_features=log2, min_samples_split=2, n_estimators=50; total time=   8.1s
# [CV] END max_depth=80, max_features=log2, min_samples_split=2, n_estimators=50; total time=   7.8s
# [CV] END max_depth=80, max_features=log2, min_samples_split=2, n_estimators=50; total time=   7.8s
# [CV] END max_depth=80, max_features=log2, min_samples_split=2, n_estimators=80; total time=  12.3s
# [CV] END max_depth=80, max_features=log2, min_samples_split=2, n_estimators=80; total time=  12.5s
# [CV] END max_depth=80, max_features=log2, min_samples_split=2, n_estimators=80; total time=  12.4s
# [CV] END max_depth=80, max_features=log2, min_samples_split=2, n_estimators=80; total time=  12.3s
# [CV] END max_depth=80, max_features=log2, min_samples_split=2, n_estimators=80; total time=  12.3s
# [CV] END max_depth=80, max_features=log2, min_samples_split=2, n_estimators=100; total time=  15.3s
# [CV] END max_depth=80, max_features=log2, min_samples_split=2, n_estimators=100; total time=  15.3s
# [CV] END max_depth=80, max_features=log2, min_samples_split=2, n_estimators=100; total time=  15.4s
# [CV] END max_depth=80, max_features=log2, min_samples_split=2, n_estimators=100; total time=  15.4s
# [CV] END max_depth=80, max_features=log2, min_samples_split=2, n_estimators=100; total time=  15.4s
# [CV] END max_depth=80, max_features=log2, min_samples_split=5, n_estimators=50; total time=   8.2s
# [CV] END max_depth=80, max_features=log2, min_samples_split=5, n_estimators=50; total time=   8.8s
# [CV] END max_depth=80, max_features=log2, min_samples_split=5, n_estimators=50; total time=   9.0s
# [CV] END max_depth=80, max_features=log2, min_samples_split=5, n_estimators=50; total time=   7.6s
# [CV] END max_depth=80, max_features=log2, min_samples_split=5, n_estimators=50; total time=   7.6s
# [CV] END max_depth=80, max_features=log2, min_samples_split=5, n_estimators=80; total time=  12.1s
# [CV] END max_depth=80, max_features=log2, min_samples_split=5, n_estimators=80; total time=  12.1s
# [CV] END max_depth=80, max_features=log2, min_samples_split=5, n_estimators=80; total time=  12.2s
# [CV] END max_depth=80, max_features=log2, min_samples_split=5, n_estimators=80; total time=  11.7s
# [CV] END max_depth=80, max_features=log2, min_samples_split=5, n_estimators=80; total time=  11.8s
# [CV] END max_depth=80, max_features=log2, min_samples_split=5, n_estimators=100; total time=  14.6s
# [CV] END max_depth=80, max_features=log2, min_samples_split=5, n_estimators=100; total time=  14.7s
# [CV] END max_depth=80, max_features=log2, min_samples_split=5, n_estimators=100; total time=  14.7s
# [CV] END max_depth=80, max_features=log2, min_samples_split=5, n_estimators=100; total time=  14.7s
# [CV] END max_depth=80, max_features=log2, min_samples_split=5, n_estimators=100; total time=  14.8s
# [CV] END max_depth=90, max_features=sqrt, min_samples_split=2, n_estimators=50; total time=   6.4s
# [CV] END max_depth=90, max_features=sqrt, min_samples_split=2, n_estimators=50; total time=   6.4s
# [CV] END max_depth=90, max_features=sqrt, min_samples_split=2, n_estimators=50; total time=   6.4s
# [CV] END max_depth=90, max_features=sqrt, min_samples_split=2, n_estimators=50; total time=   6.4s
# [CV] END max_depth=90, max_features=sqrt, min_samples_split=2, n_estimators=50; total time=   6.3s
# [CV] END max_depth=90, max_features=sqrt, min_samples_split=2, n_estimators=80; total time=  10.2s
# [CV] END max_depth=90, max_features=sqrt, min_samples_split=2, n_estimators=80; total time=  10.1s
# [CV] END max_depth=90, max_features=sqrt, min_samples_split=2, n_estimators=80; total time=  10.2s
# [CV] END max_depth=90, max_features=sqrt, min_samples_split=2, n_estimators=80; total time=  10.3s
# [CV] END max_depth=90, max_features=sqrt, min_samples_split=2, n_estimators=80; total time=  10.2s
# [CV] END max_depth=90, max_features=sqrt, min_samples_split=2, n_estimators=100; total time=  13.0s
# [CV] END max_depth=90, max_features=sqrt, min_samples_split=2, n_estimators=100; total time=  12.7s
# [CV] END max_depth=90, max_features=sqrt, min_samples_split=2, n_estimators=100; total time=  12.7s
# [CV] END max_depth=90, max_features=sqrt, min_samples_split=2, n_estimators=100; total time=  12.8s
# [CV] END max_depth=90, max_features=sqrt, min_samples_split=2, n_estimators=100; total time=  13.4s
# [CV] END max_depth=90, max_features=sqrt, min_samples_split=5, n_estimators=50; total time=   6.5s
# [CV] END max_depth=90, max_features=sqrt, min_samples_split=5, n_estimators=50; total time=   6.5s
# [CV] END max_depth=90, max_features=sqrt, min_samples_split=5, n_estimators=50; total time=   6.5s
# [CV] END max_depth=90, max_features=sqrt, min_samples_split=5, n_estimators=50; total time=   6.6s
# [CV] END max_depth=90, max_features=sqrt, min_samples_split=5, n_estimators=50; total time=   6.6s
# [CV] END max_depth=90, max_features=sqrt, min_samples_split=5, n_estimators=80; total time=  10.4s
# [CV] END max_depth=90, max_features=sqrt, min_samples_split=5, n_estimators=80; total time=  10.5s
# [CV] END max_depth=90, max_features=sqrt, min_samples_split=5, n_estimators=80; total time=  12.3s
# [CV] END max_depth=90, max_features=sqrt, min_samples_split=5, n_estimators=80; total time=  11.8s
# [CV] END max_depth=90, max_features=sqrt, min_samples_split=5, n_estimators=80; total time=  10.4s
# [CV] END max_depth=90, max_features=sqrt, min_samples_split=5, n_estimators=100; total time=  12.9s
# [CV] END max_depth=90, max_features=sqrt, min_samples_split=5, n_estimators=100; total time=  13.1s
# [CV] END max_depth=90, max_features=sqrt, min_samples_split=5, n_estimators=100; total time=  13.6s
# [CV] END max_depth=90, max_features=sqrt, min_samples_split=5, n_estimators=100; total time=  13.3s
# [CV] END max_depth=90, max_features=sqrt, min_samples_split=5, n_estimators=100; total time=  13.3s
# [CV] END max_depth=90, max_features=log2, min_samples_split=2, n_estimators=50; total time=   7.7s
# [CV] END max_depth=90, max_features=log2, min_samples_split=2, n_estimators=50; total time=   7.6s
# [CV] END max_depth=90, max_features=log2, min_samples_split=2, n_estimators=50; total time=   7.6s
# [CV] END max_depth=90, max_features=log2, min_samples_split=2, n_estimators=50; total time=   9.4s
# [CV] END max_depth=90, max_features=log2, min_samples_split=2, n_estimators=50; total time=  11.2s
# [CV] END max_depth=90, max_features=log2, min_samples_split=2, n_estimators=80; total time=  12.3s
# [CV] END max_depth=90, max_features=log2, min_samples_split=2, n_estimators=80; total time=  12.2s
# [CV] END max_depth=90, max_features=log2, min_samples_split=2, n_estimators=80; total time=  12.4s
# [CV] END max_depth=90, max_features=log2, min_samples_split=2, n_estimators=80; total time=  12.3s
# [CV] END max_depth=90, max_features=log2, min_samples_split=2, n_estimators=80; total time=  12.3s
# [CV] END max_depth=90, max_features=log2, min_samples_split=2, n_estimators=100; total time=  15.3s
# [CV] END max_depth=90, max_features=log2, min_samples_split=2, n_estimators=100; total time=  15.3s
# [CV] END max_depth=90, max_features=log2, min_samples_split=2, n_estimators=100; total time=  15.3s
# [CV] END max_depth=90, max_features=log2, min_samples_split=2, n_estimators=100; total time=  15.3s
# [CV] END max_depth=90, max_features=log2, min_samples_split=2, n_estimators=100; total time=  15.4s
# [CV] END max_depth=90, max_features=log2, min_samples_split=5, n_estimators=50; total time=   7.6s
# [CV] END max_depth=90, max_features=log2, min_samples_split=5, n_estimators=50; total time=   7.5s
# [CV] END max_depth=90, max_features=log2, min_samples_split=5, n_estimators=50; total time=   7.6s
# [CV] END max_depth=90, max_features=log2, min_samples_split=5, n_estimators=50; total time=   7.5s
# [CV] END max_depth=90, max_features=log2, min_samples_split=5, n_estimators=50; total time=   7.6s
# [CV] END max_depth=90, max_features=log2, min_samples_split=5, n_estimators=80; total time=  12.2s
# [CV] END max_depth=90, max_features=log2, min_samples_split=5, n_estimators=80; total time=  12.1s
# [CV] END max_depth=90, max_features=log2, min_samples_split=5, n_estimators=80; total time=  12.2s
# [CV] END max_depth=90, max_features=log2, min_samples_split=5, n_estimators=80; total time=  12.1s
# [CV] END max_depth=90, max_features=log2, min_samples_split=5, n_estimators=80; total time=  12.2s
# [CV] END max_depth=90, max_features=log2, min_samples_split=5, n_estimators=100; total time=  15.3s
# [CV] END max_depth=90, max_features=log2, min_samples_split=5, n_estimators=100; total time=  15.5s
# [CV] END max_depth=90, max_features=log2, min_samples_split=5, n_estimators=100; total time=  15.6s
# [CV] END max_depth=90, max_features=log2, min_samples_split=5, n_estimators=100; total time=  15.2s
# [CV] END max_depth=90, max_features=log2, min_samples_split=5, n_estimators=100; total time=  15.2s
# [CV] END max_depth=100, max_features=sqrt, min_samples_split=2, n_estimators=50; total time=   6.5s
# [CV] END max_depth=100, max_features=sqrt, min_samples_split=2, n_estimators=50; total time=   6.6s
# [CV] END max_depth=100, max_features=sqrt, min_samples_split=2, n_estimators=50; total time=   6.5s
# [CV] END max_depth=100, max_features=sqrt, min_samples_split=2, n_estimators=50; total time=   6.6s
# [CV] END max_depth=100, max_features=sqrt, min_samples_split=2, n_estimators=50; total time=   7.6s
# [CV] END max_depth=100, max_features=sqrt, min_samples_split=2, n_estimators=80; total time=  12.0s
# [CV] END max_depth=100, max_features=sqrt, min_samples_split=2, n_estimators=80; total time=  10.8s
# [CV] END max_depth=100, max_features=sqrt, min_samples_split=2, n_estimators=80; total time=  10.5s
# [CV] END max_depth=100, max_features=sqrt, min_samples_split=2, n_estimators=80; total time=  10.6s
# [CV] END max_depth=100, max_features=sqrt, min_samples_split=2, n_estimators=80; total time=  10.5s
# [CV] END max_depth=100, max_features=sqrt, min_samples_split=2, n_estimators=100; total time=  13.2s
# [CV] END max_depth=100, max_features=sqrt, min_samples_split=2, n_estimators=100; total time=  13.1s
# [CV] END max_depth=100, max_features=sqrt, min_samples_split=2, n_estimators=100; total time=  13.1s
# [CV] END max_depth=100, max_features=sqrt, min_samples_split=2, n_estimators=100; total time=  13.3s
# [CV] END max_depth=100, max_features=sqrt, min_samples_split=2, n_estimators=100; total time=  13.1s
# [CV] END max_depth=100, max_features=sqrt, min_samples_split=5, n_estimators=50; total time=   6.5s
# [CV] END max_depth=100, max_features=sqrt, min_samples_split=5, n_estimators=50; total time=   6.5s
# [CV] END max_depth=100, max_features=sqrt, min_samples_split=5, n_estimators=50; total time=   6.5s
# [CV] END max_depth=100, max_features=sqrt, min_samples_split=5, n_estimators=50; total time=   6.5s
# [CV] END max_depth=100, max_features=sqrt, min_samples_split=5, n_estimators=50; total time=   6.5s
# [CV] END max_depth=100, max_features=sqrt, min_samples_split=5, n_estimators=80; total time=  10.4s
# [CV] END max_depth=100, max_features=sqrt, min_samples_split=5, n_estimators=80; total time=  10.4s
# [CV] END max_depth=100, max_features=sqrt, min_samples_split=5, n_estimators=80; total time=  10.4s
# [CV] END max_depth=100, max_features=sqrt, min_samples_split=5, n_estimators=80; total time=  10.4s
# [CV] END max_depth=100, max_features=sqrt, min_samples_split=5, n_estimators=80; total time=  10.6s
# [CV] END max_depth=100, max_features=sqrt, min_samples_split=5, n_estimators=100; total time=  13.0s
# [CV] END max_depth=100, max_features=sqrt, min_samples_split=5, n_estimators=100; total time=  12.9s
# [CV] END max_depth=100, max_features=sqrt, min_samples_split=5, n_estimators=100; total time=  13.0s
# [CV] END max_depth=100, max_features=sqrt, min_samples_split=5, n_estimators=100; total time=  13.2s
# [CV] END max_depth=100, max_features=sqrt, min_samples_split=5, n_estimators=100; total time=  13.1s
# [CV] END max_depth=100, max_features=log2, min_samples_split=2, n_estimators=50; total time=   7.7s
# [CV] END max_depth=100, max_features=log2, min_samples_split=2, n_estimators=50; total time=   7.7s
# [CV] END max_depth=100, max_features=log2, min_samples_split=2, n_estimators=50; total time=   7.7s
# [CV] END max_depth=100, max_features=log2, min_samples_split=2, n_estimators=50; total time=   7.8s
# [CV] END max_depth=100, max_features=log2, min_samples_split=2, n_estimators=50; total time=   7.7s
# [CV] END max_depth=100, max_features=log2, min_samples_split=2, n_estimators=80; total time=  12.2s
# [CV] END max_depth=100, max_features=log2, min_samples_split=2, n_estimators=80; total time=  12.4s
# [CV] END max_depth=100, max_features=log2, min_samples_split=2, n_estimators=80; total time=  12.3s
# [CV] END max_depth=100, max_features=log2, min_samples_split=2, n_estimators=80; total time=  12.1s
# [CV] END max_depth=100, max_features=log2, min_samples_split=2, n_estimators=80; total time=  12.2s
# [CV] END max_depth=100, max_features=log2, min_samples_split=2, n_estimators=100; total time=  15.3s
# [CV] END max_depth=100, max_features=log2, min_samples_split=2, n_estimators=100; total time=  15.3s
# [CV] END max_depth=100, max_features=log2, min_samples_split=2, n_estimators=100; total time=  15.4s
# [CV] END max_depth=100, max_features=log2, min_samples_split=2, n_estimators=100; total time=  15.5s
# [CV] END max_depth=100, max_features=log2, min_samples_split=2, n_estimators=100; total time=  15.4s
# [CV] END max_depth=100, max_features=log2, min_samples_split=5, n_estimators=50; total time=   7.6s
# [CV] END max_depth=100, max_features=log2, min_samples_split=5, n_estimators=50; total time=   7.5s
# [CV] END max_depth=100, max_features=log2, min_samples_split=5, n_estimators=50; total time=   7.6s
# [CV] END max_depth=100, max_features=log2, min_samples_split=5, n_estimators=50; total time=   7.7s
# [CV] END max_depth=100, max_features=log2, min_samples_split=5, n_estimators=50; total time=   7.6s
# [CV] END max_depth=100, max_features=log2, min_samples_split=5, n_estimators=80; total time=  13.5s
# [CV] END max_depth=100, max_features=log2, min_samples_split=5, n_estimators=80; total time=  13.0s
# [CV] END max_depth=100, max_features=log2, min_samples_split=5, n_estimators=80; total time=  12.2s
# [CV] END max_depth=100, max_features=log2, min_samples_split=5, n_estimators=80; total time=  12.1s
# [CV] END max_depth=100, max_features=log2, min_samples_split=5, n_estimators=80; total time=  12.2s
# [CV] END max_depth=100, max_features=log2, min_samples_split=5, n_estimators=100; total time=  15.5s
# [CV] END max_depth=100, max_features=log2, min_samples_split=5, n_estimators=100; total time=  15.2s
# [CV] END max_depth=100, max_features=log2, min_samples_split=5, n_estimators=100; total time=  16.2s
# [CV] END max_depth=100, max_features=log2, min_samples_split=5, n_estimators=100; total time=  16.3s
# [CV] END max_depth=100, max_features=log2, min_samples_split=5, n_estimators=100; total time=  15.3s
# {'max_depth': 30, 'max_features': 'log2', 'min_samples_split': 2, 'n_estimators': 100}
# Accuracy : 99.07%
# Precision : 0.98
# Recall : 0.99
# F1 score : 0.99

# %%
print(f'The accuracy of final Final_Random_Forest on Train_set is {metrics.accuracy_score(y_train, final_randomforest.predict(X_train))*100:.2f}%.')
print(f'The accuracy of final Final_Random_Forest on Test_set is {metrics.accuracy_score(y_test, final_randomforest.predict(X_test))*100:.2f}%.')
# Out:
# The accuracy of final Final_Random_Forest on Train_set is 100.00%.
# The accuracy of final Final_Random_Forest on Test_set is 99.07%.

# %% [markdown]
# **Hyperparameter tuning XGBoost**

# %%
grid = {
    'learning_rate': [0.01, 0.05, 0.1, 0.2],
    'max_depth': [3, 5, 7, 9],
    'n_estimators': [50, 100, 200],
    'subsample': [0.6, 0.8, 1.0],
    'colsample_bytree': [0.6, 0.8, 1.0],
    'gamma': [0, 0.1, 0.5, 1]
}

with mlflow.start_run(run_name="final_xgb"):
    gs = GridSearchCV(estimator=xgb, param_grid=grid, cv = 5, verbose=2, scoring='f1')
    gs.fit(X_train, y_train)
    best_param = gs.best_params_
    print(best_param)
    
    final_xgb = gs.best_estimator_
    y_pred = final_xgb.predict(X_test)

    result = evaluate_preds(y_test, y_pred);
    
    for param in best_param:
        mlflow.log_param(param, best_param[param])
    mlflow.log_metric("accuracy", result['accuracy'])
    mlflow.log_metric("precision", result['precision'])
    mlflow.log_metric("recall", result['recall'])
    mlflow.log_metric("f1-score", result['f1'])
    mlflow.sklearn.log_model(final_xgb, "model")
    mlflow.sklearn.save_model(final_xgb, "./Models/final_xgb")
# Out:
# Fitting 5 folds for each of 1728 candidates, totalling 8640 fits
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.6; total time=   0.7s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.6; total time=   0.7s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.6; total time=   0.7s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.6; total time=   0.6s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.6; total time=   0.7s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.8; total time=   0.6s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.8; total time=   0.6s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.8; total time=   0.6s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.8; total time=   0.6s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.8; total time=   0.6s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=50, subsample=1.0; total time=   0.4s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=50, subsample=1.0; total time=   0.4s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=50, subsample=1.0; total time=   0.4s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=50, subsample=1.0; total time=   0.4s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=50, subsample=1.0; total time=   0.4s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.6; total time=   1.4s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.6; total time=   1.4s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.6; total time=   1.4s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.6; total time=   1.4s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.6; total time=   1.4s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.8; total time=   1.2s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.8; total time=   1.2s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.8; total time=   1.2s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.8; total time=   1.2s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.8; total time=   1.2s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=1.0; total time=   0.9s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=1.0; total time=   0.8s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=1.0; total time=   0.8s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=1.0; total time=   0.9s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=1.0; total time=   0.8s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.6; total time=   2.8s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.6; total time=   2.8s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.6; total time=   2.8s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.6; total time=   2.8s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.6; total time=   2.8s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.8; total time=   2.6s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.8; total time=   2.5s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.8; total time=   2.5s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.8; total time=   2.6s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.8; total time=   2.7s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=200, subsample=1.0; total time=   1.8s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=200, subsample=1.0; total time=   1.8s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=200, subsample=1.0; total time=   1.8s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=200, subsample=1.0; total time=   1.8s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=200, subsample=1.0; total time=   1.8s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=5, n_estimators=50, subsample=0.6; total time=   1.0s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=5, n_estimators=50, subsample=0.6; total time=   1.0s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=5, n_estimators=50, subsample=0.6; total time=   1.0s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=5, n_estimators=50, subsample=0.6; total time=   1.0s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=5, n_estimators=50, subsample=0.6; total time=   1.0s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=5, n_estimators=50, subsample=0.8; total time=   0.9s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=5, n_estimators=50, subsample=0.8; total time=   1.0s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=5, n_estimators=50, subsample=0.8; total time=   1.0s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=5, n_estimators=50, subsample=0.8; total time=   1.0s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=5, n_estimators=50, subsample=0.8; total time=   1.0s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=5, n_estimators=50, subsample=1.0; total time=   0.8s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=5, n_estimators=50, subsample=1.0; total time=   0.9s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=5, n_estimators=50, subsample=1.0; total time=   1.0s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=5, n_estimators=50, subsample=1.0; total time=   1.0s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=5, n_estimators=50, subsample=1.0; total time=   0.9s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.6; total time=   2.5s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.6; total time=   2.6s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.6; total time=   2.6s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.6; total time=   2.6s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.6; total time=   2.4s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.8; total time=   2.2s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.8; total time=   1.9s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.8; total time=   1.9s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.8; total time=   1.9s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.8; total time=   1.9s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=5, n_estimators=100, subsample=1.0; total time=   1.4s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=5, n_estimators=100, subsample=1.0; total time=   1.4s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=5, n_estimators=100, subsample=1.0; total time=   1.4s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=5, n_estimators=100, subsample=1.0; total time=   1.4s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=5, n_estimators=100, subsample=1.0; total time=   1.4s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=5, n_estimators=200, subsample=0.6; total time=   4.1s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=5, n_estimators=200, subsample=0.6; total time=   4.1s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=5, n_estimators=200, subsample=0.6; total time=   4.1s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=5, n_estimators=200, subsample=0.6; total time=   4.1s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=5, n_estimators=200, subsample=0.6; total time=   4.2s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=5, n_estimators=200, subsample=0.8; total time=   4.0s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=5, n_estimators=200, subsample=0.8; total time=   3.8s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=5, n_estimators=200, subsample=0.8; total time=   3.8s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=5, n_estimators=200, subsample=0.8; total time=   3.9s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=5, n_estimators=200, subsample=0.8; total time=   3.9s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=5, n_estimators=200, subsample=1.0; total time=   3.0s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=5, n_estimators=200, subsample=1.0; total time=   3.0s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=5, n_estimators=200, subsample=1.0; total time=   2.9s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=5, n_estimators=200, subsample=1.0; total time=   2.9s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=5, n_estimators=200, subsample=1.0; total time=   3.0s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=7, n_estimators=50, subsample=0.6; total time=   1.4s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=7, n_estimators=50, subsample=0.6; total time=   1.4s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=7, n_estimators=50, subsample=0.6; total time=   1.4s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=7, n_estimators=50, subsample=0.6; total time=   1.4s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=7, n_estimators=50, subsample=0.6; total time=   1.4s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=7, n_estimators=50, subsample=0.8; total time=   1.3s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=7, n_estimators=50, subsample=0.8; total time=   1.3s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=7, n_estimators=50, subsample=0.8; total time=   1.3s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=7, n_estimators=50, subsample=0.8; total time=   1.3s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=7, n_estimators=50, subsample=0.8; total time=   1.3s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=7, n_estimators=50, subsample=1.0; total time=   1.0s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=7, n_estimators=50, subsample=1.0; total time=   1.0s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=7, n_estimators=50, subsample=1.0; total time=   1.1s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=7, n_estimators=50, subsample=1.0; total time=   1.0s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=7, n_estimators=50, subsample=1.0; total time=   1.0s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=7, n_estimators=100, subsample=0.6; total time=   2.8s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=7, n_estimators=100, subsample=0.6; total time=   2.8s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=7, n_estimators=100, subsample=0.6; total time=   2.8s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=7, n_estimators=100, subsample=0.6; total time=   2.8s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=7, n_estimators=100, subsample=0.6; total time=   2.8s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=7, n_estimators=100, subsample=0.8; total time=   2.6s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=7, n_estimators=100, subsample=0.8; total time=   2.6s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=7, n_estimators=100, subsample=0.8; total time=   2.6s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=7, n_estimators=100, subsample=0.8; total time=   2.6s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=7, n_estimators=100, subsample=0.8; total time=   2.7s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=7, n_estimators=100, subsample=1.0; total time=   2.1s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=7, n_estimators=100, subsample=1.0; total time=   2.1s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=7, n_estimators=100, subsample=1.0; total time=   2.1s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=7, n_estimators=100, subsample=1.0; total time=   2.1s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=7, n_estimators=100, subsample=1.0; total time=   2.1s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=7, n_estimators=200, subsample=0.6; total time=   5.6s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=7, n_estimators=200, subsample=0.6; total time=   5.7s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=7, n_estimators=200, subsample=0.6; total time=   5.7s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=7, n_estimators=200, subsample=0.6; total time=   5.7s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=7, n_estimators=200, subsample=0.6; total time=   5.7s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=7, n_estimators=200, subsample=0.8; total time=   5.2s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=7, n_estimators=200, subsample=0.8; total time=   5.2s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=7, n_estimators=200, subsample=0.8; total time=   5.2s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=7, n_estimators=200, subsample=0.8; total time=   5.3s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=7, n_estimators=200, subsample=0.8; total time=   5.3s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=7, n_estimators=200, subsample=1.0; total time=   4.2s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=7, n_estimators=200, subsample=1.0; total time=   4.2s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=7, n_estimators=200, subsample=1.0; total time=   4.2s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=7, n_estimators=200, subsample=1.0; total time=   4.3s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=7, n_estimators=200, subsample=1.0; total time=   4.2s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=9, n_estimators=50, subsample=0.6; total time=   1.8s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=9, n_estimators=50, subsample=0.6; total time=   1.8s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=9, n_estimators=50, subsample=0.6; total time=   1.8s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=9, n_estimators=50, subsample=0.6; total time=   1.7s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=9, n_estimators=50, subsample=0.6; total time=   1.7s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=9, n_estimators=50, subsample=0.8; total time=   1.7s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=9, n_estimators=50, subsample=0.8; total time=   1.7s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=9, n_estimators=50, subsample=0.8; total time=   1.6s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=9, n_estimators=50, subsample=0.8; total time=   1.6s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=9, n_estimators=50, subsample=0.8; total time=   1.6s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=9, n_estimators=50, subsample=1.0; total time=   1.4s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=9, n_estimators=50, subsample=1.0; total time=   1.4s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=9, n_estimators=50, subsample=1.0; total time=   1.4s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=9, n_estimators=50, subsample=1.0; total time=   1.4s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=9, n_estimators=50, subsample=1.0; total time=   1.4s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=9, n_estimators=100, subsample=0.6; total time=   3.6s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=9, n_estimators=100, subsample=0.6; total time=   3.6s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=9, n_estimators=100, subsample=0.6; total time=   3.6s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=9, n_estimators=100, subsample=0.6; total time=   3.6s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=9, n_estimators=100, subsample=0.6; total time=   3.6s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=9, n_estimators=100, subsample=0.8; total time=   3.3s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=9, n_estimators=100, subsample=0.8; total time=   3.3s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=9, n_estimators=100, subsample=0.8; total time=   3.3s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=9, n_estimators=100, subsample=0.8; total time=   3.3s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=9, n_estimators=100, subsample=0.8; total time=   3.3s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=9, n_estimators=100, subsample=1.0; total time=   2.8s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=9, n_estimators=100, subsample=1.0; total time=   2.8s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=9, n_estimators=100, subsample=1.0; total time=   2.8s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=9, n_estimators=100, subsample=1.0; total time=   2.8s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=9, n_estimators=100, subsample=1.0; total time=   2.8s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=9, n_estimators=200, subsample=0.6; total time=   7.2s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=9, n_estimators=200, subsample=0.6; total time=   7.2s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=9, n_estimators=200, subsample=0.6; total time=   7.2s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=9, n_estimators=200, subsample=0.6; total time=   7.3s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=9, n_estimators=200, subsample=0.6; total time=   7.8s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=9, n_estimators=200, subsample=0.8; total time=   6.7s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=9, n_estimators=200, subsample=0.8; total time=   6.7s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=9, n_estimators=200, subsample=0.8; total time=   7.0s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=9, n_estimators=200, subsample=0.8; total time=   6.7s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=9, n_estimators=200, subsample=0.8; total time=   6.8s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=9, n_estimators=200, subsample=1.0; total time=   5.9s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=9, n_estimators=200, subsample=1.0; total time=   5.6s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=9, n_estimators=200, subsample=1.0; total time=   5.6s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=9, n_estimators=200, subsample=1.0; total time=   5.6s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=9, n_estimators=200, subsample=1.0; total time=   5.6s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=3, n_estimators=50, subsample=0.6; total time=   0.8s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=3, n_estimators=50, subsample=0.6; total time=   0.8s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=3, n_estimators=50, subsample=0.6; total time=   0.8s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=3, n_estimators=50, subsample=0.6; total time=   0.8s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=3, n_estimators=50, subsample=0.6; total time=   0.8s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=3, n_estimators=50, subsample=0.8; total time=   0.7s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=3, n_estimators=50, subsample=0.8; total time=   0.7s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=3, n_estimators=50, subsample=0.8; total time=   0.7s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=3, n_estimators=50, subsample=0.8; total time=   0.7s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=3, n_estimators=50, subsample=0.8; total time=   0.7s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=3, n_estimators=50, subsample=1.0; total time=   0.5s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=3, n_estimators=50, subsample=1.0; total time=   0.5s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=3, n_estimators=50, subsample=1.0; total time=   0.5s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=3, n_estimators=50, subsample=1.0; total time=   0.5s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=3, n_estimators=50, subsample=1.0; total time=   0.5s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=3, n_estimators=100, subsample=0.6; total time=   1.6s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=3, n_estimators=100, subsample=0.6; total time=   1.6s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=3, n_estimators=100, subsample=0.6; total time=   1.6s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=3, n_estimators=100, subsample=0.6; total time=   1.6s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=3, n_estimators=100, subsample=0.6; total time=   1.6s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=3, n_estimators=100, subsample=0.8; total time=   1.4s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=3, n_estimators=100, subsample=0.8; total time=   1.4s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=3, n_estimators=100, subsample=0.8; total time=   1.4s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=3, n_estimators=100, subsample=0.8; total time=   1.4s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=3, n_estimators=100, subsample=0.8; total time=   1.4s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=3, n_estimators=100, subsample=1.0; total time=   1.0s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=3, n_estimators=100, subsample=1.0; total time=   1.0s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=3, n_estimators=100, subsample=1.0; total time=   1.0s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=3, n_estimators=100, subsample=1.0; total time=   1.0s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=3, n_estimators=100, subsample=1.0; total time=   1.0s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=3, n_estimators=200, subsample=0.6; total time=   3.2s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=3, n_estimators=200, subsample=0.6; total time=   3.2s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=3, n_estimators=200, subsample=0.6; total time=   3.2s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=3, n_estimators=200, subsample=0.6; total time=   3.2s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=3, n_estimators=200, subsample=0.6; total time=   3.2s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=3, n_estimators=200, subsample=0.8; total time=   2.8s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=3, n_estimators=200, subsample=0.8; total time=   2.8s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=3, n_estimators=200, subsample=0.8; total time=   2.8s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=3, n_estimators=200, subsample=0.8; total time=   2.9s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=3, n_estimators=200, subsample=0.8; total time=   2.9s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=3, n_estimators=200, subsample=1.0; total time=   1.9s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=3, n_estimators=200, subsample=1.0; total time=   2.0s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=3, n_estimators=200, subsample=1.0; total time=   1.9s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=3, n_estimators=200, subsample=1.0; total time=   2.0s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=3, n_estimators=200, subsample=1.0; total time=   1.9s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=5, n_estimators=50, subsample=0.6; total time=   1.1s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=5, n_estimators=50, subsample=0.6; total time=   1.1s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=5, n_estimators=50, subsample=0.6; total time=   1.1s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=5, n_estimators=50, subsample=0.6; total time=   1.2s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=5, n_estimators=50, subsample=0.6; total time=   1.1s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=5, n_estimators=50, subsample=0.8; total time=   1.0s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=5, n_estimators=50, subsample=0.8; total time=   1.0s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=5, n_estimators=50, subsample=0.8; total time=   1.0s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=5, n_estimators=50, subsample=0.8; total time=   1.0s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=5, n_estimators=50, subsample=0.8; total time=   1.0s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=5, n_estimators=50, subsample=1.0; total time=   0.8s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=5, n_estimators=50, subsample=1.0; total time=   0.8s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=5, n_estimators=50, subsample=1.0; total time=   0.8s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=5, n_estimators=50, subsample=1.0; total time=   0.8s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=5, n_estimators=50, subsample=1.0; total time=   0.8s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=5, n_estimators=100, subsample=0.6; total time=   2.2s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=5, n_estimators=100, subsample=0.6; total time=   2.3s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=5, n_estimators=100, subsample=0.6; total time=   2.3s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=5, n_estimators=100, subsample=0.6; total time=   2.3s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=5, n_estimators=100, subsample=0.6; total time=   2.2s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=5, n_estimators=100, subsample=0.8; total time=   2.1s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=5, n_estimators=100, subsample=0.8; total time=   2.0s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=5, n_estimators=100, subsample=0.8; total time=   2.1s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=5, n_estimators=100, subsample=0.8; total time=   2.0s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=5, n_estimators=100, subsample=0.8; total time=   2.0s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=5, n_estimators=100, subsample=1.0; total time=   1.6s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=5, n_estimators=100, subsample=1.0; total time=   1.5s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=5, n_estimators=100, subsample=1.0; total time=   1.5s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=5, n_estimators=100, subsample=1.0; total time=   1.6s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=5, n_estimators=100, subsample=1.0; total time=   1.6s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=5, n_estimators=200, subsample=0.6; total time=   4.5s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=5, n_estimators=200, subsample=0.6; total time=   4.5s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=5, n_estimators=200, subsample=0.6; total time=   4.5s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=5, n_estimators=200, subsample=0.6; total time=   4.6s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=5, n_estimators=200, subsample=0.6; total time=   4.5s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=5, n_estimators=200, subsample=0.8; total time=   4.6s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=5, n_estimators=200, subsample=0.8; total time=   4.7s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=5, n_estimators=200, subsample=0.8; total time=   4.2s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=5, n_estimators=200, subsample=0.8; total time=   4.2s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=5, n_estimators=200, subsample=0.8; total time=   4.5s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=5, n_estimators=200, subsample=1.0; total time=   3.3s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=5, n_estimators=200, subsample=1.0; total time=   3.7s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=5, n_estimators=200, subsample=1.0; total time=   3.3s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=5, n_estimators=200, subsample=1.0; total time=   3.2s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=5, n_estimators=200, subsample=1.0; total time=   3.2s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=7, n_estimators=50, subsample=0.6; total time=   1.5s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=7, n_estimators=50, subsample=0.6; total time=   1.5s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=7, n_estimators=50, subsample=0.6; total time=   1.5s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=7, n_estimators=50, subsample=0.6; total time=   1.5s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=7, n_estimators=50, subsample=0.6; total time=   1.5s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=7, n_estimators=50, subsample=0.8; total time=   1.4s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=7, n_estimators=50, subsample=0.8; total time=   1.4s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=7, n_estimators=50, subsample=0.8; total time=   1.4s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=7, n_estimators=50, subsample=0.8; total time=   1.4s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=7, n_estimators=50, subsample=0.8; total time=   1.4s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=7, n_estimators=50, subsample=1.0; total time=   1.1s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=7, n_estimators=50, subsample=1.0; total time=   1.1s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=7, n_estimators=50, subsample=1.0; total time=   1.1s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=7, n_estimators=50, subsample=1.0; total time=   1.1s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=7, n_estimators=50, subsample=1.0; total time=   1.1s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=7, n_estimators=100, subsample=0.6; total time=   3.1s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=7, n_estimators=100, subsample=0.6; total time=   3.0s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=7, n_estimators=100, subsample=0.6; total time=   3.0s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=7, n_estimators=100, subsample=0.6; total time=   3.1s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=7, n_estimators=100, subsample=0.6; total time=   3.0s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=7, n_estimators=100, subsample=0.8; total time=   2.7s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=7, n_estimators=100, subsample=0.8; total time=   2.7s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=7, n_estimators=100, subsample=0.8; total time=   2.7s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=7, n_estimators=100, subsample=0.8; total time=   2.8s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=7, n_estimators=100, subsample=0.8; total time=   2.8s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=7, n_estimators=100, subsample=1.0; total time=   2.2s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=7, n_estimators=100, subsample=1.0; total time=   2.2s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=7, n_estimators=100, subsample=1.0; total time=   2.2s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=7, n_estimators=100, subsample=1.0; total time=   2.2s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=7, n_estimators=100, subsample=1.0; total time=   2.2s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=7, n_estimators=200, subsample=0.6; total time=   6.0s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=7, n_estimators=200, subsample=0.6; total time=   6.5s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=7, n_estimators=200, subsample=0.6; total time=   6.1s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=7, n_estimators=200, subsample=0.6; total time=   6.2s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=7, n_estimators=200, subsample=0.6; total time=   6.0s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=7, n_estimators=200, subsample=0.8; total time=   5.5s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=7, n_estimators=200, subsample=0.8; total time=   5.5s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=7, n_estimators=200, subsample=0.8; total time=   5.5s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=7, n_estimators=200, subsample=0.8; total time=   5.7s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=7, n_estimators=200, subsample=0.8; total time=   5.5s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=7, n_estimators=200, subsample=1.0; total time=   4.4s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=7, n_estimators=200, subsample=1.0; total time=   4.4s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=7, n_estimators=200, subsample=1.0; total time=   4.4s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=7, n_estimators=200, subsample=1.0; total time=   4.4s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=7, n_estimators=200, subsample=1.0; total time=   4.4s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=9, n_estimators=50, subsample=0.6; total time=   1.9s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=9, n_estimators=50, subsample=0.6; total time=   1.9s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=9, n_estimators=50, subsample=0.6; total time=   1.9s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=9, n_estimators=50, subsample=0.6; total time=   1.8s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=9, n_estimators=50, subsample=0.6; total time=   1.8s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=9, n_estimators=50, subsample=0.8; total time=   1.7s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=9, n_estimators=50, subsample=0.8; total time=   1.7s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=9, n_estimators=50, subsample=0.8; total time=   1.8s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=9, n_estimators=50, subsample=0.8; total time=   1.7s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=9, n_estimators=50, subsample=0.8; total time=   1.7s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=9, n_estimators=50, subsample=1.0; total time=   1.4s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=9, n_estimators=50, subsample=1.0; total time=   1.4s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=9, n_estimators=50, subsample=1.0; total time=   1.4s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=9, n_estimators=50, subsample=1.0; total time=   1.5s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=9, n_estimators=50, subsample=1.0; total time=   1.4s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=9, n_estimators=100, subsample=0.6; total time=   3.7s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=9, n_estimators=100, subsample=0.6; total time=   3.7s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=9, n_estimators=100, subsample=0.6; total time=   3.7s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=9, n_estimators=100, subsample=0.6; total time=   3.8s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=9, n_estimators=100, subsample=0.6; total time=   3.7s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=9, n_estimators=100, subsample=0.8; total time=   3.5s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=9, n_estimators=100, subsample=0.8; total time=   3.4s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=9, n_estimators=100, subsample=0.8; total time=   3.6s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=9, n_estimators=100, subsample=0.8; total time=   3.6s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=9, n_estimators=100, subsample=0.8; total time=   3.5s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=9, n_estimators=100, subsample=1.0; total time=   2.9s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=9, n_estimators=100, subsample=1.0; total time=   2.9s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=9, n_estimators=100, subsample=1.0; total time=   2.9s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=9, n_estimators=100, subsample=1.0; total time=   2.9s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=9, n_estimators=100, subsample=1.0; total time=   2.9s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=9, n_estimators=200, subsample=0.6; total time=   7.4s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=9, n_estimators=200, subsample=0.6; total time=   7.5s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=9, n_estimators=200, subsample=0.6; total time=   7.5s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=9, n_estimators=200, subsample=0.6; total time=   7.5s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=9, n_estimators=200, subsample=0.6; total time=   7.4s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=9, n_estimators=200, subsample=0.8; total time=   7.0s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=9, n_estimators=200, subsample=0.8; total time=   6.9s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=9, n_estimators=200, subsample=0.8; total time=   6.9s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=9, n_estimators=200, subsample=0.8; total time=   6.9s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=9, n_estimators=200, subsample=0.8; total time=   7.0s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=9, n_estimators=200, subsample=1.0; total time=   5.8s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=9, n_estimators=200, subsample=1.0; total time=   5.8s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=9, n_estimators=200, subsample=1.0; total time=   5.8s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=9, n_estimators=200, subsample=1.0; total time=   5.8s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=9, n_estimators=200, subsample=1.0; total time=   5.9s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.1, max_depth=3, n_estimators=50, subsample=0.6; total time=   0.8s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.1, max_depth=3, n_estimators=50, subsample=0.6; total time=   0.8s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.1, max_depth=3, n_estimators=50, subsample=0.6; total time=   0.8s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.1, max_depth=3, n_estimators=50, subsample=0.6; total time=   0.8s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.1, max_depth=3, n_estimators=50, subsample=0.6; total time=   0.8s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.1, max_depth=3, n_estimators=50, subsample=0.8; total time=   0.7s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.1, max_depth=3, n_estimators=50, subsample=0.8; total time=   0.8s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.1, max_depth=3, n_estimators=50, subsample=0.8; total time=   0.7s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.1, max_depth=3, n_estimators=50, subsample=0.8; total time=   0.7s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.1, max_depth=3, n_estimators=50, subsample=0.8; total time=   0.7s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.1, max_depth=3, n_estimators=50, subsample=1.0; total time=   0.5s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.1, max_depth=3, n_estimators=50, subsample=1.0; total time=   0.5s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.1, max_depth=3, n_estimators=50, subsample=1.0; total time=   0.5s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.1, max_depth=3, n_estimators=50, subsample=1.0; total time=   0.5s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.1, max_depth=3, n_estimators=50, subsample=1.0; total time=   0.5s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.6; total time=   1.6s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.6; total time=   1.6s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.6; total time=   1.7s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.6; total time=   1.6s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.6; total time=   1.6s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.8; total time=   1.5s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.8; total time=   1.5s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.8; total time=   1.5s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.8; total time=   1.4s
# ...
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=5, n_estimators=50, subsample=0.8; total time=   1.0s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=5, n_estimators=50, subsample=0.8; total time=   1.0s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=5, n_estimators=50, subsample=1.0; total time=   0.8s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=5, n_estimators=50, subsample=1.0; total time=   0.8s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=5, n_estimators=50, subsample=1.0; total time=   0.8s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=5, n_estimators=50, subsample=1.0; total time=   0.8s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=5, n_estimators=50, subsample=1.0; total time=   0.8s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=5, n_estimators=100, subsample=0.6; total time=   2.5s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=5, n_estimators=100, subsample=0.6; total time=   2.3s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=5, n_estimators=100, subsample=0.6; total time=   2.3s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=5, n_estimators=100, subsample=0.6; total time=   2.3s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=5, n_estimators=100, subsample=0.6; total time=   2.3s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=5, n_estimators=100, subsample=0.8; total time=   2.1s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=5, n_estimators=100, subsample=0.8; total time=   2.1s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=5, n_estimators=100, subsample=0.8; total time=   2.1s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=5, n_estimators=100, subsample=0.8; total time=   2.2s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=5, n_estimators=100, subsample=0.8; total time=   2.2s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=5, n_estimators=100, subsample=1.0; total time=   1.7s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=5, n_estimators=100, subsample=1.0; total time=   1.6s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=5, n_estimators=100, subsample=1.0; total time=   1.6s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=5, n_estimators=100, subsample=1.0; total time=   1.6s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=5, n_estimators=100, subsample=1.0; total time=   1.6s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=5, n_estimators=200, subsample=0.6; total time=   4.6s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=5, n_estimators=200, subsample=0.6; total time=   4.8s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=5, n_estimators=200, subsample=0.6; total time=   4.6s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=5, n_estimators=200, subsample=0.6; total time=   4.7s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=5, n_estimators=200, subsample=0.6; total time=   4.6s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=5, n_estimators=200, subsample=0.8; total time=   4.2s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=5, n_estimators=200, subsample=0.8; total time=   4.4s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=5, n_estimators=200, subsample=0.8; total time=   4.3s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=5, n_estimators=200, subsample=0.8; total time=   4.3s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=5, n_estimators=200, subsample=0.8; total time=   4.2s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=5, n_estimators=200, subsample=1.0; total time=   3.4s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=5, n_estimators=200, subsample=1.0; total time=   3.4s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=5, n_estimators=200, subsample=1.0; total time=   3.3s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=5, n_estimators=200, subsample=1.0; total time=   3.3s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=5, n_estimators=200, subsample=1.0; total time=   3.3s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=7, n_estimators=50, subsample=0.6; total time=   1.6s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=7, n_estimators=50, subsample=0.6; total time=   1.6s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=7, n_estimators=50, subsample=0.6; total time=   1.6s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=7, n_estimators=50, subsample=0.6; total time=   1.8s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=7, n_estimators=50, subsample=0.6; total time=   1.6s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=7, n_estimators=50, subsample=0.8; total time=   1.5s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=7, n_estimators=50, subsample=0.8; total time=   1.5s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=7, n_estimators=50, subsample=0.8; total time=   1.5s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=7, n_estimators=50, subsample=0.8; total time=   1.4s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=7, n_estimators=50, subsample=0.8; total time=   1.5s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=7, n_estimators=50, subsample=1.0; total time=   1.2s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=7, n_estimators=50, subsample=1.0; total time=   1.2s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=7, n_estimators=50, subsample=1.0; total time=   1.2s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=7, n_estimators=50, subsample=1.0; total time=   1.2s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=7, n_estimators=50, subsample=1.0; total time=   1.5s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=7, n_estimators=100, subsample=0.6; total time=   3.7s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=7, n_estimators=100, subsample=0.6; total time=   3.1s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=7, n_estimators=100, subsample=0.6; total time=   3.2s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=7, n_estimators=100, subsample=0.6; total time=   3.2s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=7, n_estimators=100, subsample=0.6; total time=   3.2s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=7, n_estimators=100, subsample=0.8; total time=   2.8s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=7, n_estimators=100, subsample=0.8; total time=   2.9s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=7, n_estimators=100, subsample=0.8; total time=   3.1s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=7, n_estimators=100, subsample=0.8; total time=   2.9s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=7, n_estimators=100, subsample=0.8; total time=   2.9s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=7, n_estimators=100, subsample=1.0; total time=   2.4s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=7, n_estimators=100, subsample=1.0; total time=   2.4s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=7, n_estimators=100, subsample=1.0; total time=   2.3s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=7, n_estimators=100, subsample=1.0; total time=   2.3s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=7, n_estimators=100, subsample=1.0; total time=   2.6s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=7, n_estimators=200, subsample=0.6; total time=   6.5s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=7, n_estimators=200, subsample=0.6; total time=   6.4s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=7, n_estimators=200, subsample=0.6; total time=   6.6s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=7, n_estimators=200, subsample=0.6; total time=   6.5s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=7, n_estimators=200, subsample=0.6; total time=   6.5s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=7, n_estimators=200, subsample=0.8; total time=   6.0s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=7, n_estimators=200, subsample=0.8; total time=   6.0s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=7, n_estimators=200, subsample=0.8; total time=   6.2s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=7, n_estimators=200, subsample=0.8; total time=   6.1s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=7, n_estimators=200, subsample=0.8; total time=   6.0s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=7, n_estimators=200, subsample=1.0; total time=   4.9s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=7, n_estimators=200, subsample=1.0; total time=   4.9s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=7, n_estimators=200, subsample=1.0; total time=   4.8s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=7, n_estimators=200, subsample=1.0; total time=   4.8s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=7, n_estimators=200, subsample=1.0; total time=   4.9s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=9, n_estimators=50, subsample=0.6; total time=   2.0s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=9, n_estimators=50, subsample=0.6; total time=   2.0s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=9, n_estimators=50, subsample=0.6; total time=   2.1s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=9, n_estimators=50, subsample=0.6; total time=   2.0s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=9, n_estimators=50, subsample=0.6; total time=   2.1s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=9, n_estimators=50, subsample=0.8; total time=   2.0s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=9, n_estimators=50, subsample=0.8; total time=   1.9s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=9, n_estimators=50, subsample=0.8; total time=   1.9s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=9, n_estimators=50, subsample=0.8; total time=   1.9s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=9, n_estimators=50, subsample=0.8; total time=   2.1s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=9, n_estimators=50, subsample=1.0; total time=   1.7s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=9, n_estimators=50, subsample=1.0; total time=   1.6s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=9, n_estimators=50, subsample=1.0; total time=   1.6s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=9, n_estimators=50, subsample=1.0; total time=   1.7s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=9, n_estimators=50, subsample=1.0; total time=   1.6s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=9, n_estimators=100, subsample=0.6; total time=   4.2s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=9, n_estimators=100, subsample=0.6; total time=   4.1s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=9, n_estimators=100, subsample=0.6; total time=   4.4s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=9, n_estimators=100, subsample=0.6; total time=   4.2s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=9, n_estimators=100, subsample=0.6; total time=   4.4s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=9, n_estimators=100, subsample=0.8; total time=   3.8s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=9, n_estimators=100, subsample=0.8; total time=   3.8s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=9, n_estimators=100, subsample=0.8; total time=   4.0s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=9, n_estimators=100, subsample=0.8; total time=   3.8s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=9, n_estimators=100, subsample=0.8; total time=   3.9s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=9, n_estimators=100, subsample=1.0; total time=   3.3s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=9, n_estimators=100, subsample=1.0; total time=   3.4s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=9, n_estimators=100, subsample=1.0; total time=   3.4s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=9, n_estimators=100, subsample=1.0; total time=   3.2s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=9, n_estimators=100, subsample=1.0; total time=   3.3s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=9, n_estimators=200, subsample=0.6; total time=   8.2s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=9, n_estimators=200, subsample=0.6; total time=   8.4s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=9, n_estimators=200, subsample=0.6; total time=   8.3s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=9, n_estimators=200, subsample=0.6; total time=   8.4s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=9, n_estimators=200, subsample=0.6; total time=   8.4s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=9, n_estimators=200, subsample=0.8; total time=   7.7s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=9, n_estimators=200, subsample=0.8; total time=   7.8s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=9, n_estimators=200, subsample=0.8; total time=   7.7s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=9, n_estimators=200, subsample=0.8; total time=   8.0s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=9, n_estimators=200, subsample=0.8; total time=   8.0s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=9, n_estimators=200, subsample=1.0; total time=   6.8s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=9, n_estimators=200, subsample=1.0; total time=   6.5s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=9, n_estimators=200, subsample=1.0; total time=   6.6s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=9, n_estimators=200, subsample=1.0; total time=   6.7s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.2, max_depth=9, n_estimators=200, subsample=1.0; total time=   6.6s
# {'colsample_bytree': 1.0, 'gamma': 0, 'learning_rate': 0.2, 'max_depth': 9, 'n_estimators': 200, 'subsample': 0.8}
# Accuracy : 97.33%
# Precision : 0.98
# Recall : 0.95
# F1 score : 0.96

# %%
print(f'The accuracy of final Final_XGBoost on Train_set is {metrics.accuracy_score(y_train, final_xgb.predict(X_train))*100:.2f}%.')
print(f'The accuracy of final Final_XGBoost on Test_set is {metrics.accuracy_score(y_test, final_xgb.predict(X_test))*100:.2f}%.')
# Out:
# The accuracy of final Final_XGBoost on Train_set is 98.31%.
# The accuracy of final Final_XGBoost on Test_set is 97.33%.

# %% [markdown]
# # 6. Results

# %%
mlflow.search_runs()
# Out:
#                               run_id experiment_id    status  \
# 0   aee56dbb7fb742f6960dcf096f63b398             0  FINISHED
# 1   abb72ef2fc2a47208ba400aefd87b647             0  FINISHED
# 2   c4e8edeb7ecc4e9ea841d12f28b47c72             0  FINISHED
# 3   474ada5df62a4b0ea99ddc3879953e77             0  FINISHED
# 4   0bb2f79c0e374ade82fe7e976f571178             0  FINISHED
# 5   6c720c5ebc214baeabaab9bd2d2bf6ac             0  FINISHED
# 6   c6d948fb33964760a7106b3bd5c1942e             0  FINISHED
# 7   cde12e5d94ae434caefe1e6e4ee26e7a             0    FAILED
# 8   e2af980dc4db4799b9689c4a42260e40             0  FINISHED
# 9   432a5efd3892494ebaaba708bdc4657e             0  FINISHED
# 10  8dd00070708046b6a9a334748d27abfe             0  FINISHED
# 11  0bef1581e1284f7189cfb6d85029ba06             0  FINISHED
# 12  b8260713f8844cb28ec2a5b52d519035             0    FAILED
# 13  4465157fe5d74787a24e0fdd42c9819a             0  FINISHED
# 14  c4961fc027164ccdb1ea41f5fbda0db2             0    FAILED
# 15  a76276748d30439d9dba452dbd7a0119             0  FINISHED
# 16  983de5db53f443c2bf850681a2c81777             0  FINISHED
# 17  06a02a39af4647e8b05a2d6aef933030             0  FINISHED
# 18  24702fe7b4f54106b7db014900eff2a9             0  FINISHED
#
#                                          artifact_uri  \
# 0   file:///C:/Users/SUJAN/Desktop/Loan%20Approval...
# 1   file:///C:/Users/SUJAN/Desktop/Loan%20Approval...
# 2   file:///C:/Users/SUJAN/Desktop/Loan%20Approval...
# 3   file:///C:/Users/SUJAN/Desktop/Loan%20Approval...
# 4   file:///C:/Users/SUJAN/Desktop/Loan%20Approval...
# 5   file:///C:/Users/SUJAN/Desktop/Loan%20Approval...
# 6   file:///C:/Users/SUJAN/Desktop/Loan%20Approval...
# 7   file:///C:/Users/SUJAN/Desktop/Loan%20Approval...
# 8   file:///C:/Users/SUJAN/Desktop/Loan%20Approval...
# 9   file:///C:/Users/SUJAN/Desktop/Loan%20Approval...
# 10  file:///C:/Users/SUJAN/Desktop/Loan%20Approval...
# 11  file:///C:/Users/SUJAN/Desktop/Loan%20Approval...
# 12  file:///C:/Users/SUJAN/Desktop/Loan%20Approval...
# 13  file:///C:/Users/SUJAN/Desktop/Loan%20Approval...
# 14  file:///C:/Users/SUJAN/Desktop/Loan%20Approval...
# 15  file:///C:/Users/SUJAN/Desktop/Loan%20Approval...
# 16  file:///C:/Users/SUJAN/Desktop/Loan%20Approval...
# 17  file:///C:/Users/SUJAN/Desktop/Loan%20Approval...
# 18  file:///C:/Users/SUJAN/Desktop/Loan%20Approval...
#
#                          start_time                         end_time  \
# 0  2023-08-18 15:59:23.750000+00:00 2023-08-18 22:56:44.398000+00:00
# 1  2023-08-18 14:29:24.435000+00:00 2023-08-18 15:59:17.424000+00:00
# 2  2023-08-18 14:29:14.642000+00:00 2023-08-18 14:29:24.362000+00:00
# 3  2023-08-18 14:27:50.375000+00:00 2023-08-18 14:29:14.177000+00:00
# 4  2023-08-18 14:27:32.982000+00:00 2023-08-18 14:27:50.217000+00:00
# 5  2023-08-18 14:25:44.287000+00:00 2023-08-18 14:27:26.067000+00:00
# 6  2023-08-18 14:25:24.050000+00:00 2023-08-18 14:25:30.255000+00:00
# 7  2023-08-18 14:24:16.119000+00:00 2023-08-18 14:24:24.912000+00:00
# 8  2023-08-16 09:06:17.407000+00:00 2023-08-16 17:13:40.227000+00:00
# 9  2023-08-16 07:32:33.383000+00:00 2023-08-16 09:06:09.664000+00:00
# 10 2023-08-16 07:20:58.004000+00:00 2023-08-16 07:21:10.613000+00:00
# 11 2023-08-16 07:14:26.650000+00:00 2023-08-16 07:15:55.104000+00:00
# 12 2023-08-16 07:10:41.116000+00:00 2023-08-16 07:12:07.215000+00:00
# 13 2023-08-16 07:10:01.543000+00:00 2023-08-16 07:10:22.125000+00:00
# 14 2023-08-16 07:09:12.364000+00:00 2023-08-16 07:09:31.800000+00:00
# 15 2023-08-16 07:08:21.078000+00:00 2023-08-16 07:08:42.441000+00:00
# 16 2023-08-16 07:03:36.371000+00:00 2023-08-16 07:05:24.824000+00:00
# 17 2023-08-16 07:01:53.691000+00:00 2023-08-16 07:02:03.475000+00:00
# 18 2023-08-16 06:59:47.654000+00:00 2023-08-16 07:01:11.731000+00:00
#
#     metrics.recall  metrics.precision  metrics.f1-score  metrics.accuracy  \
# 0             0.95               0.98              0.96              0.97
# 1             0.99               0.98              0.99              0.99
# 2             0.10               0.50              0.16              0.65
# 3             0.23               0.64              0.34              0.68
# 4             0.76               0.92              0.83              0.89
# 5             0.99               0.98              0.99              0.99
# 6             0.99               0.97              0.98              0.99
# 7             0.99               0.97              0.98              0.99
# 8             0.95               0.98              0.96              0.97
# 9             0.99               0.98              0.99              0.99
# 10            0.10               0.50              0.16              0.65
# 11            0.23               0.64              0.34              0.68
# 12            0.23               0.64              0.34              0.68
# 13            0.76               0.92              0.83              0.89
# 14            0.76               0.92              0.83              0.89
# 15            0.76               0.92              0.83              0.89
# 16            0.99               0.98              0.99              0.99
# 17            0.99               0.97              0.98              0.99
# 18            0.23               0.64              0.34              0.68
#
#     ... params.max_depth params.learning_rate params.max_features  \
# 0   ...                9                  0.2                None
# 1   ...               30                 None                log2
# 2   ...             None                 None                None
# 3   ...             None                 None                None
# 4   ...             None                 None                None
# 5   ...             None                 None                None
# 6   ...             None                 None                None
# 7   ...             None                 None                None
# 8   ...                9                  0.2                None
# 9   ...               30                 None                log2
# 10  ...             None                 None                None
# 11  ...             None                 None                None
# 12  ...             None                 None                None
# 13  ...             None                 None                None
# 14  ...             None                 None                None
# 15  ...             None                 None                None
# 16  ...             None                 None                None
# 17  ...             None                 None                None
# 18  ...             None                 None                None
#
#    params.min_samples_split params.random_state  \
# 0                      None                None
# 1                         2                None
# 2                      None                  10
# 3                      None                  10
# 4                      None                  10
# 5                      None                  10
# 6                      None                  10
# 7                      None                  10
# 8                      None                None
# 9                         2                None
# 10                     None                  10
# 11                     None                  10
# 12                     None                  10
# 13                     None                  10
# 14                     None                  10
# 15                     None                  10
# 16                     None                  10
# 17                     None                  10
# 18                     None                  10
#
#                               tags.mlflow.source.name  tags.mlflow.runName  \
# 0   C:\Users\SUJAN\anaconda3\lib\site-packages\ipy...            final_xgb
# 1   C:\Users\SUJAN\anaconda3\lib\site-packages\ipy...   final_randomforest
# 2   C:\Users\SUJAN\anaconda3\lib\site-packages\ipy...  logistic_regression
# 3   C:\Users\SUJAN\anaconda3\lib\site-packages\ipy...     gradientboosting
# 4   C:\Users\SUJAN\anaconda3\lib\site-packages\ipy...                  xgb
# 5   C:\Users\SUJAN\anaconda3\lib\site-packages\ipy...         randomforest
# 6   C:\Users\SUJAN\anaconda3\lib\site-packages\ipy...         decisiontree
# 7   C:\Users\SUJAN\anaconda3\lib\site-packages\ipy...         decisiontree
# 8   C:\Users\SUJAN\anaconda3\lib\site-packages\ipy...            final_xgb
# 9   C:\Users\SUJAN\anaconda3\lib\site-packages\ipy...   final_randomforest
# 10  C:\Users\SUJAN\anaconda3\lib\site-packages\ipy...  logistic_regression
# 11  C:\Users\SUJAN\anaconda3\lib\site-packages\ipy...     gradientboosting
# 12  C:\Users\SUJAN\anaconda3\lib\site-packages\ipy...     gradientboosting
# 13  C:\Users\SUJAN\anaconda3\lib\site-packages\ipy...                  xgb
# 14  C:\Users\SUJAN\anaconda3\lib\site-packages\ipy...                  xgb
# 15  C:\Users\SUJAN\anaconda3\lib\site-packages\ipy...                  xgb
# 16  C:\Users\SUJAN\anaconda3\lib\site-packages\ipy...         randomforest
# 17  C:\Users\SUJAN\anaconda3\lib\site-packages\ipy...         decisiontree
# 18  C:\Users\SUJAN\anaconda3\lib\site-packages\ipy...     gradientboosting
#
#    tags.mlflow.user                      tags.mlflow.log-model.history  \
# 0             SUJAN  [{"run_id": "aee56dbb7fb742f6960dcf096f63b398"...
# 1             SUJAN  [{"run_id": "abb72ef2fc2a47208ba400aefd87b647"...
# 2             SUJAN  [{"run_id": "c4e8edeb7ecc4e9ea841d12f28b47c72"...
# 3             SUJAN  [{"run_id": "474ada5df62a4b0ea99ddc3879953e77"...
# 4             SUJAN  [{"run_id": "0bb2f79c0e374ade82fe7e976f571178"...
# 5             SUJAN  [{"run_id": "6c720c5ebc214baeabaab9bd2d2bf6ac"...
# 6             SUJAN  [{"run_id": "c6d948fb33964760a7106b3bd5c1942e"...
# 7             SUJAN  [{"run_id": "cde12e5d94ae434caefe1e6e4ee26e7a"...
# 8             SUJAN  [{"run_id": "e2af980dc4db4799b9689c4a42260e40"...
# 9             SUJAN  [{"run_id": "432a5efd3892494ebaaba708bdc4657e"...
# 10            SUJAN  [{"run_id": "8dd00070708046b6a9a334748d27abfe"...
# 11            SUJAN  [{"run_id": "0bef1581e1284f7189cfb6d85029ba06"...
# 12            SUJAN  [{"run_id": "b8260713f8844cb28ec2a5b52d519035"...
# 13            SUJAN  [{"run_id": "4465157fe5d74787a24e0fdd42c9819a"...
# 14            SUJAN  [{"run_id": "c4961fc027164ccdb1ea41f5fbda0db2"...
# 15            SUJAN  [{"run_id": "a76276748d30439d9dba452dbd7a0119"...
# 16            SUJAN  [{"run_id": "983de5db53f443c2bf850681a2c81777"...
# 17            SUJAN  [{"run_id": "06a02a39af4647e8b05a2d6aef933030"...
# 18            SUJAN  [{"run_id": "24702fe7b4f54106b7db014900eff2a9"...
#
#    tags.mlflow.source.type
# 0                    LOCAL
# 1                    LOCAL
# 2                    LOCAL
# 3                    LOCAL
# 4                    LOCAL
# 5                    LOCAL
# 6                    LOCAL
# 7                    LOCAL
# 8                    LOCAL
# 9                    LOCAL
# 10                   LOCAL
# 11                   LOCAL
# 12                   LOCAL
# 13                   LOCAL
# 14                   LOCAL
# 15                   LOCAL
# 16                   LOCAL
# 17                   LOCAL
# 18                   LOCAL
#
# [19 rows x 24 columns]

# %% [markdown]
# # 7. Final Model
# Although the random forest model gave higher accuracy, it seemed like overfitting, so we chose the XGBoost model, which has less variance between the train set and the test set.

# %%
model_uri = 'runs:/aee56dbb7fb742f6960dcf096f63b398/model'

model = mlflow.sklearn.load_model(model_uri = model_uri)

# %%
model.get_params()
# Out:
# {'objective': 'binary:logistic',
#  'use_label_encoder': None,
#  'base_score': None,
#  'booster': None,
#  'callbacks': None,
#  'colsample_bylevel': None,
#  'colsample_bynode': None,
#  'colsample_bytree': 1.0,
#  'early_stopping_rounds': None,
#  'enable_categorical': False,
#  'eval_metric': None,
#  'feature_types': None,
#  'gamma': 0,
#  'gpu_id': None,
#  'grow_policy': None,
#  'importance_type': None,
#  'interaction_constraints': None,
#  'learning_rate': 0.2,
#  'max_bin': None,
#  'max_cat_threshold': None,
#  'max_cat_to_onehot': None,
#  'max_delta_step': None,
#  'max_depth': 9,
#  'max_leaves': None,
#  'min_child_weight': None,
#  'missing': nan,
#  'monotone_constraints': None,
#  'n_estimators': 200,
#  'n_jobs': None,
#  'num_parallel_tree': None,
#  'predictor': None,
#  'random_state': None,
#  'reg_alpha': None,
#  'reg_lambda': None,
#  'sampling_method': None,
#  'scale_pos_weight': None,
#  'subsample': 0.8,
#  'tree_method': None,
#  'validate_parameters': None,
#  'verbosity': None}

# %%
y_pred = model.predict(X_test)

evaluate_preds(y_test, y_pred);
# Out:
# Accuracy : 97.33%
# Precision : 0.98
# Recall : 0.95
# F1 score : 0.96

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98     41456
#            1       0.98      0.95      0.96     22759
#
#     accuracy                           0.97     64215
#    macro avg       0.97      0.97      0.97     64215
# weighted avg       0.97      0.97      0.97     64215

# %%
sns.heatmap(metrics.confusion_matrix(y_pred, y_test), annot=True, fmt='2.0f', cmap='summer').set(title="XGBoost Confusion Matrix");

# %% [markdown]
# # 7. Conclusion
# From the above project, we trained our model using XGBoost algorithm with 98.31% accuracy.

# %% [markdown]
# # Prediction

# %%
def getPredictions(martial, house_O, car_O, profession, current_jy, current_hy, income, age):
    model_uri = 'runs:/aee56dbb7fb742f6960dcf096f63b398/model'

    model = mlflow.sklearn.load_model(model_uri = model_uri)
    encoders = load(open('./Models/encoders.pkl', 'rb'))

    categorical_data = [martial, house_O, car_O, profession]
    for i, j in enumerate(categorical_data):
        categorical_data[i] = [j]
    categorical_columns = ['Married/Single', 'House_Ownership', 'Car_Ownership', 'Profession']

    for i, column in enumerate(categorical_columns):
        label_encoder = encoders[column]
        categorical_data[i] = label_encoder.transform(categorical_data[i])
     
    categorical_data = np.squeeze(categorical_data)

    if income <= 2506726:
        income = 0
    elif 2506726 < income <= 5003310:
        income = 1
    elif 5003310 < income <=7477502:
        income = 2
    else:
        income = 3

    if age <= 32:
        age = 0
    elif 32 < age <= 44:
        age = 1
    elif 44 < age <= 56:
        age = 2
    elif 56 < age <= 68:
        age = 3
    else:
        age = 4   
        
    data = [[categorical_data[0], categorical_data[1], categorical_data[2], categorical_data[3], current_jy, current_hy, income, age]]
    df = pd.DataFrame(data , columns = model.feature_names_in_)
        
    prediction = model.predict(df)
    if prediction == 0:
        return 'eligible'
    elif prediction == 1:
        return 'not eligible'
    else:
        return 'error'

# %%
getPredictions('married', 'owned', 'no', 'Software_Developer', 3, 11, 3600000, 23)
# Out:
# 'not eligible'

# %%
getPredictions('single', 'rented', 'no', 'Mechanical_engineer', 3, 13, 1303834, 23)
# Out:
# 'eligible'
